# %%
import pandas as pd
#import numpy as np
csv_test = pd.read_csv('test2.csv', delimiter = ',')
#csv_test.head()

# %%
csv_test.rename(columns={'_ws.col.Time' : 'time',
                        'ip.flags' : 'ip_flags',
                        'ip.len' : 'ip_len',
                        'tcp.hdr_len' : 'tcp_hdr_len',
                        'tcp.flags' : 'tcp_flags',
                        'tcp.window_size_value' : 'tcp_window_size_value',
                        'ip.flags.rb' : 'ip_flags_resbit',
                        'ip.flags.df' : 'ip_flags_dontfrag',
                        'ip.flags.mf' : 'ip_flags_morefrag',
                        'tcp.flags.cwr' : 'tcp_flags_cong_window_reduced',
                        'tcp.flags.ecn' : 'tcp_flags_explicit_cong_notif',
                        'tcp.flags.urg' : 'tcp_flags_urg_pointer',
                        'tcp.flags.ack' : 'tcp_flags_ack',
                        'tcp.flags.push' : 'tcp_flags_push',
                        'tcp.flags.reset' : 'tcp_flags_reset',
                        'tcp.flags.syn' : 'tcp_flags_syn',
                        'tcp.flags.fin' : 'tcp_flags_fin',
                        'ip.frag_offset' : 'ip_frag_offset'}, inplace=True)
df = pd.DataFrame(csv_test)
df.head()
# Out:
#        time  ip_flags_resbit  ip_flags_dontfrag  ip_flags_morefrag  \
# 0  0.000000              0.0                0.0                0.0
# 1  0.001252              0.0                0.0                0.0
# 2  3.313382              0.0                1.0                0.0
# 3  3.313489              0.0                1.0                0.0
# 4  3.329486              0.0                1.0                0.0
#
#    ip_frag_offset  ip_len  tcp_hdr_len  tcp_flags_cong_window_reduced  \
# 0             0.0  1089.0          NaN                            NaN
# 1             0.0  1076.0          NaN                            NaN
# 2             0.0    40.0         20.0                            0.0
# 3             0.0    40.0         20.0                            0.0
# 4             0.0    52.0         32.0                            0.0
#
#    tcp_flags_explicit_cong_notif  tcp_flags_urg_pointer  tcp_flags_ack  \
# ...

# %%
df['stalling_event'] = 0
df.loc[(df.time > 36.8) & (df.time < 70.8), 'stalling_event'] = '1'
df.loc[(df.time > 71.1) & (df.time < 104.7), 'stalling_event'] = '1'
df.loc[(df.time > 105) & (df.time < 153.4), 'stalling_event'] = '1'
#df.loc[(df.time > 36.5) & (df.time < 38), 'stalling_event'] = '1'
#df.loc[(df.time > 36.8) & (df.time < 37.1), 'stalling_event'] = '1'
#df.loc[(df.time > 70.8) & (df.time < 104.9), 'stalling_event'] = '1'
#df.loc[(df.time > 71.1) & (df.time < 71.3), 'stalling_event'] = '1'
#df.loc[(df.time > 104.7) & (df.time < 138.4), 'stalling_event'] = '1'
#df.loc[(df.time > 105) & (df.time < 105.2), 'stalling_event'] = '1'
#df.loc[(df.time > 153.4) & (df.time < 201.9), 'stalling_event'] = '1'

# %%
export_csv = df.to_csv (r'C:\Users\angel\OneDrive\Documentos\Universidad\Cuarto\TFG\full_test_flag_fragmented.csv', index = None, header=True)
