# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
import os
import tempfile 


from sklearn import preprocessing
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score, classification_report
from collections import Counter

import tensorflow as tf
import keras


import warnings
warnings.filterwarnings("ignore")
colors = np.array(['#0101DF','#DF0101','#01DF01'])

rs = 42
def compute_metrics (y_te2,y_p,string):
    print('\n %s'%string)
    print('CONFUSION MATRIX')
    print(metrics.confusion_matrix(y_te2,y_p))
    print(classification_report(y_te2, y_p))
    print('\nROC CURVE: %2.2f'%roc_auc_score(y_te2,y_p))

def Ratio10(y,string):
    suma = Counter(y)[0]+Counter(y)[1]
    print('\n'+string)  
    print(Counter(y))
    print('0: %3.2f%%\n1: %3.2f%%' % (100*Counter(y)[0]/suma,100*Counter(y)[1]/suma))

def histo(data,var):
    fig=plt.figure()
    sns.countplot(var,data=data,palette=colors)
    plt.title('0/1 Distribution (0: No Stalling || 1: Stalling Event',fontsize=14)
    plt.show()
    
def plot_loss(history, label, n):
    # Use a log scale to show the wide range of values.
    plt.semilogy(history.epoch,  
                 history.history['loss'],
                 color=colors[n], 
                 label='Train '+label
                 )
    plt.semilogy(history.epoch,
                 history.history['val_loss'],
                 color=colors[n], 
                 label='Val '+label,
                 linestyle="--")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

def plot_metrics(history):
    metrics =  ['loss', 'auc', 'precision', 'recall']
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.5,1])
        else:
            plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
  cm = metrics.confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))
  

def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = metrics.roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5,100.5])
    plt.ylim([-0.5,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('../../output/df_general.csv', sep=',')
split = 0.8
del dataset['No.']
del dataset['Protocol']
del dataset['ip_len']
del dataset['prebuffering']
del dataset['Time']

dataset = dataset.fillna(dataset.mean())
neg, pos = np.bincount(dataset['stalling_event'])
total = neg + pos
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print(dataset.columns)
Ratio10(dataset['stalling_event'],'dataset[stalling_event]')
histo(dataset,'stalling_event')
# Out:
# Index(['∆t', 'pkt_len', 'tcp_hea_len', 'tcp_flag_ack', 'tcp_flag_cwr',
#        'tcp_flag_ecn', 'tcp_flag_urg', 'tcp_flag_psh', 'tcp_flag_rst',
#        'tcp_flag_syn', 'tcp_flag_fin', 'tcp_win_si2', 'delay', 'capture',
#        'stalling_event'],
#       dtype='object')
#
# dataset[stalling_event]
# Counter({0: 1426905, 1: 113031})
# 0: 92.66%
# 1: 7.34%

# %%
from random import randint
'''X_train = [None] * (len(dataset.columns)-1)
X_test = [None] * (len(dataset.columns)-1)'''

X_train = np.array([None]*12)
X_test = np.array([None]*12)
y_train = list()
y_test = list()

grouped = dataset.groupby(['delay','capture']) 
#print(grouped.mean())

for id, data in grouped:
    spl = int(data.shape[0] * split)
    restspl = int(data.shape[0] * (1-split))
    randnum = randint(0,restspl)
    
    X_train = np.vstack((X_train,data.values[randnum:randnum+spl,:-3]))
    X_test = np.vstack((X_test,data.values[0:randnum-1,:-3]))
    X_test = np.vstack((X_test,data.values[randnum+spl:,:-3]))
    
    y_train.extend(data.values[randnum:randnum+spl,-1])
    y_test.extend(data.values[0:randnum-1,-1])
    y_test.extend(data.values[randnum+spl:,-1])

X_train = X_train[1:]
X_test = X_test[1:]

X_train = pd.DataFrame(data=X_train,columns=dataset.columns[:-3])
X_test= pd.DataFrame(data=X_test,columns=dataset.columns[:-3])
del dataset['delay']
del dataset['capture']

# %%
mms = preprocessing.MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)

# %%
y_test = list(map(int,y_test))
y_train = list(map(int,y_train))
Ratio10(y_test,'y_test')
Ratio10(y_train,'y_train')
# Out:
# y_test
# Counter({0: 301160, 1: 6792})
# 0: 97.79%
# 1: 2.21%
#
# y_train
# Counter({0: 1125686, 1: 106238})
# 0: 91.38%
# 1: 8.62%

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.TrueNegatives(name='tn'),
    tf.keras.metrics.FalseNegatives(name='fn'),
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
]

EPOCHS = 100
BATCH_SIZE = 2048

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', 
                                                  verbose=1,
                                                  patience=10,
                                                  mode='max',
                                                  restore_best_weights=True)

# %%
n_features = X_train.shape[1]
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(16,activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# 1231924/1231924 [==============================] - 4s 4us/step
# Loss: 0.6133

# %%
initial_bias = np.log([pos/neg])
print(initial_bias)
# Out:
# [-2.53560092]

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(16,activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid',bias_initializer=keras.initializers.Constant(initial_bias)))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
#  - ETA: 4s
# Loss: 0.2955

# %%
initial_weights = os.path.join(tempfile.mkdtemp(),'initial_weights')
model.save_weights(initial_weights)

# %%
model_baseline = keras.Sequential()
model_baseline.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model_baseline.add(keras.layers.Dropout(0.5))
model_baseline.add(keras.layers.Dense(16,activation='relu'))
model_baseline.add(keras.layers.Dropout(0.5))
model_baseline.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model_baseline.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model_baseline.summary()
print('Compiled NN...')

baseline_history = model_baseline.fit(X_train,
                             y_train,
                             batch_size=BATCH_SIZE,
                             epochs=EPOCHS,
                             callbacks = [early_stopping],
                             validation_split=0.2
                             )
# Out:
# Built NN...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.3379 - tp: 2632.9087 - fp: 25604.3887 - tn: 2688214.7500 - fn: 241986.2344 - accuracy: 0.9094 - precision: 0.0943 - recall: 0.0108 - auc: 0.5048 - val_loss: 0.5254 - val_tp: 2725.0000 - val_fp: 26909.0000 - val_tn: 3250789.5000 - val_fn: 293880.3125 - val_accuracy: 0.9103 - val_precision: 0.0920 - val_recall: 0.0092 - val_auc: 0.5001
# Epoch 2/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2693 - tp: 2725.0000 - fp: 26910.7578 - tn: 3812638.2500 - fn: 348085.7812 - accuracy: 0.9104 - precision: 0.0920 - recall: 0.0078 - auc: 0.4952 - val_loss: 0.5152 - val_tp: 2725.0000 - val_fp: 26911.0000 - val_tn: 4376473.5000 - val_fn: 400118.4688 - val_accuracy: 0.9112 - val_precision: 0.0919 - val_recall: 0.0068 - val_auc: 0.4968
# Epoch 3/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2593 - tp: 2725.0000 - fp: 26911.0000 - tn: 4938412.5000 - fn: 454237.1562 - accuracy: 0.9112 - precision: 0.0919 - recall: 0.0060 - auc: 0.4975 - val_loss: 0.5161 - val_tp: 2725.0000 - val_fp: 26911.0000 - val_tn: 5502159.5000 - val_fn: 506356.3438 - val_accuracy: 0.9117 - val_precision: 0.0919 - val_recall: 0.0054 - val_auc: 0.4988
# Epoch 4/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2544 - tp: 2725.0000 - fp: 26911.6523 - tn: 6063971.0000 - fn: 560599.1875 - accuracy: 0.9117 - precision: 0.0919 - recall: 0.0048 - auc: 0.4998 - val_loss: 0.5204 - val_tp: 2725.0000 - val_fp: 26913.0000 - val_tn: 6627847.0000 - val_fn: 612594.5625 - val_accuracy: 0.9120 - val_precision: 0.0919 - val_recall: 0.0044 - val_auc: 0.5004
# Epoch 5/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2517 - tp: 2725.0000 - fp: 26914.6680 - tn: 7189735.5000 - fn: 666754.6250 - accuracy: 0.9120 - precision: 0.0919 - recall: 0.0041 - auc: 0.5006 - val_loss: 0.5176 - val_tp: 2725.0000 - val_fp: 26916.0000 - val_tn: 7753527.5000 - val_fn: 718832.3750 - val_accuracy: 0.9123 - val_precision: 0.0919 - val_recall: 0.0038 - val_auc: 0.5016
# Epoch 6/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2492 - tp: 2725.0000 - fp: 26916.0000 - tn: 8315486.5000 - fn: 772931.3125 - accuracy: 0.9123 - precision: 0.0919 - recall: 0.0035 - auc: 0.5028 - val_loss: 0.5155 - val_tp: 2725.0000 - val_fp: 26916.0000 - val_tn: 8879208.0000 - val_fn: 825070.1875 - val_accuracy: 0.9125 - val_precision: 0.0919 - val_recall: 0.0033 - val_auc: 0.5035
# Epoch 7/100
#  - ETA: 5s - loss: 0.2465 - tp: 2725.0000 - fp: 26916.0000 - tn: 9012133.0000 - fn: 849457.8750 - accuracy: 0.9114 - precision: 0.0919 - recall: 0.0032 - auc: 0.5031
# Epoch 8/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2450 - tp: 2725.1743 - fp: 26918.9121 - tn: 10566882.0000 - fn: 985378.8125 - accuracy: 0.9126 - precision: 0.0919 - recall: 0.0028 - auc: 0.5059 - val_loss: 0.5193 - val_tp: 2726.0000 - val_fp: 26922.0000 - val_tn: 11130577.0000 - val_fn: 1037545.5625 - val_accuracy: 0.9127 - val_precision: 0.0919 - val_recall: 0.0026 - val_auc: 0.5062
# Epoch 9/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2435 - tp: 2726.0000 - fp: 26925.2070 - tn: 11692464.0000 - fn: 1091719.1250 - accuracy: 0.9127 - precision: 0.0919 - recall: 0.0025 - auc: 0.5066 - val_loss: 0.5173 - val_tp: 2726.0000 - val_fp: 26932.0000 - val_tn: 12256244.0000 - val_fn: 1143783.1250 - val_accuracy: 0.9128 - val_precision: 0.0919 - val_recall: 0.0024 - val_auc: 0.5072
# Epoch 10/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2418 - tp: 2727.1763 - fp: 26936.0820 - tn: 12818168.0000 - fn: 1197919.6250 - accuracy: 0.9128 - precision: 0.0919 - recall: 0.0023 - auc: 0.5082 - val_loss: 0.5164 - val_tp: 2730.0000 - val_fp: 26943.0000 - val_tn: 13381942.0000 - val_fn: 1250018.0000 - val_accuracy: 0.9129 - val_precision: 0.0920 - val_recall: 0.0022 - val_auc: 0.5089
# Epoch 11/100
#  - ETA: 0s - loss: 0.2413 - tp: 2734.8540 - fp: 26953.0000 - tn: 13875854.0000 - fn: 1299435.3750 - accuracy: 0.9128 - precision: 0.0921 - recall: 0.0021 - auc: 0.5097
# Epoch 12/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2401 - tp: 2746.0227 - fp: 26974.3867 - tn: 15069467.0000 - fn: 1410409.5000 - accuracy: 0.9129 - precision: 0.0924 - recall: 0.0019 - auc: 0.5108 - val_loss: 0.5185 - val_tp: 2755.0000 - val_fp: 26981.0000 - val_tn: 15633252.0000 - val_fn: 1462468.2500 - val_accuracy: 0.9130 - val_precision: 0.0926 - val_recall: 0.0019 - val_auc: 0.5114
# Epoch 13/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2397 - tp: 2764.2966 - fp: 26999.3027 - tn: 16195065.0000 - fn: 1516696.1250 - accuracy: 0.9130 - precision: 0.0929 - recall: 0.0018 - auc: 0.5120 - val_loss: 0.5197 - val_tp: 2775.0000 - val_fp: 27025.0000 - val_tn: 16758893.0000 - val_fn: 1568686.5000 - val_accuracy: 0.9131 - val_precision: 0.0931 - val_recall: 0.0018 - val_auc: 0.5126
# Epoch 14/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2393 - tp: 2790.8943 - fp: 27056.4395 - tn: 17320826.0000 - fn: 1622776.8750 - accuracy: 0.9130 - precision: 0.0935 - recall: 0.0017 - auc: 0.5133 - val_loss: 0.5179 - val_tp: 2809.0000 - val_fp: 27084.0000 - val_tn: 17884512.0000 - val_fn: 1674889.6250 - val_accuracy: 0.9131 - val_precision: 0.0940 - val_recall: 0.0017 - val_auc: 0.5142
# Epoch 15/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2392 - tp: 2816.4543 - fp: 27117.7871 - tn: 18446350.0000 - fn: 1729048.0000 - accuracy: 0.9131 - precision: 0.0941 - recall: 0.0016 - auc: 0.5152 - val_loss: 0.5200 - val_tp: 2823.0000 - val_fp: 27141.0000 - val_tn: 19010124.0000 - val_fn: 1781113.5000 - val_accuracy: 0.9132 - val_precision: 0.0942 - val_recall: 0.0016 - val_auc: 0.5158
# Epoch 16/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2391 - tp: 2840.6038 - fp: 27167.3730 - tn: 19572064.0000 - fn: 1835194.8750 - accuracy: 0.9131 - precision: 0.0947 - recall: 0.0015 - auc: 0.5166 - val_loss: 0.5206 - val_tp: 2868.0000 - val_fp: 27205.0000 - val_tn: 20135752.0000 - val_fn: 1887305.7500 - val_accuracy: 0.9132 - val_precision: 0.0954 - val_recall: 0.0015 - val_auc: 0.5172
# Epoch 17/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2391 - tp: 2884.8860 - fp: 27233.7070 - tn: 20697622.0000 - fn: 1941451.0000 - accuracy: 0.9132 - precision: 0.0958 - recall: 0.0015 - auc: 0.5180 - val_loss: 0.5224 - val_tp: 2903.0000 - val_fp: 27265.0000 - val_tn: 21261396.0000 - val_fn: 1993510.3750 - val_accuracy: 0.9132 - val_precision: 0.0962 - val_recall: 0.0015 - val_auc: 0.5185
# Epoch 18/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2389 - tp: 2914.5581 - fp: 27293.0156 - tn: 21823360.0000 - fn: 2047556.2500 - accuracy: 0.9132 - precision: 0.0965 - recall: 0.0014 - auc: 0.5192 - val_loss: 0.5218 - val_tp: 2934.0000 - val_fp: 27322.0000 - val_tn: 22387016.0000 - val_fn: 2099717.7500 - val_accuracy: 0.9132 - val_precision: 0.0970 - val_recall: 0.0014 - val_auc: 0.5198
# Epoch 19/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2388 - tp: 2966.0747 - fp: 27371.0352 - tn: 22948866.0000 - fn: 2153849.2500 - accuracy: 0.9132 - precision: 0.0978 - recall: 0.0014 - auc: 0.5206 - val_loss: 0.5210 - val_tp: 2993.0000 - val_fp: 27418.0000 - val_tn: 23512598.0000 - val_fn: 2205895.5000 - val_accuracy: 0.9133 - val_precision: 0.0984 - val_recall: 0.0014 - val_auc: 0.5211
# Epoch 20/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2386 - tp: 3027.3589 - fp: 27480.5332 - tn: 24074330.0000 - fn: 2260131.0000 - accuracy: 0.9132 - precision: 0.0992 - recall: 0.0013 - auc: 0.5218 - val_loss: 0.5213 - val_tp: 3058.0000 - val_fp: 27537.0000 - val_tn: 24638182.0000 - val_fn: 2312069.5000 - val_accuracy: 0.9133 - val_precision: 0.1000 - val_recall: 0.0013 - val_auc: 0.5225
# Epoch 21/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2385 - tp: 3079.6951 - fp: 27588.4043 - tn: 25200044.0000 - fn: 2366173.0000 - accuracy: 0.9133 - precision: 0.1004 - recall: 0.0013 - auc: 0.5233 - val_loss: 0.5210 - val_tp: 3101.0000 - val_fp: 27637.0000 - val_tn: 25763730.0000 - val_fn: 2418263.7500 - val_accuracy: 0.9133 - val_precision: 0.1009 - val_recall: 0.0013 - val_auc: 0.5239
# Epoch 22/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2385 - tp: 3122.1597 - fp: 27687.4766 - tn: 26325554.0000 - fn: 2472442.0000 - accuracy: 0.9133 - precision: 0.1013 - recall: 0.0013 - auc: 0.5247 - val_loss: 0.5202 - val_tp: 3146.0000 - val_fp: 27731.0000 - val_tn: 26889346.0000 - val_fn: 2524456.2500 - val_accuracy: 0.9133 - val_precision: 0.1019 - val_recall: 0.0012 - val_auc: 0.5253
# Epoch 23/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2385 - tp: 3181.4026 - fp: 27779.4902 - tn: 27451200.0000 - fn: 2578559.0000 - accuracy: 0.9133 - precision: 0.1028 - recall: 0.0012 - auc: 0.5261 - val_loss: 0.5219 - val_tp: 3205.0000 - val_fp: 27826.0000 - val_tn: 28014910.0000 - val_fn: 2630634.7500 - val_accuracy: 0.9133 - val_precision: 0.1033 - val_recall: 0.0012 - val_auc: 0.5266
# Epoch 24/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2384 - tp: 3231.9543 - fp: 27873.9004 - tn: 28576800.0000 - fn: 2684723.0000 - accuracy: 0.9133 - precision: 0.1039 - recall: 0.0012 - auc: 0.5273 - val_loss: 0.5238 - val_tp: 3262.0000 - val_fp: 27928.0000 - val_tn: 29140478.0000 - val_fn: 2736817.0000 - val_accuracy: 0.9134 - val_precision: 0.1046 - val_recall: 0.0012 - val_auc: 0.5278
# Epoch 25/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2384 - tp: 3286.3257 - fp: 27982.2715 - tn: 29702344.0000 - fn: 2790945.0000 - accuracy: 0.9133 - precision: 0.1051 - recall: 0.0012 - auc: 0.5284 - val_loss: 0.5243 - val_tp: 3315.0000 - val_fp: 28040.0000 - val_tn: 30266086.0000 - val_fn: 2843002.7500 - val_accuracy: 0.9134 - val_precision: 0.1057 - val_recall: 0.0012 - val_auc: 0.5286
# Epoch 26/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2384 - tp: 3341.8464 - fp: 28086.9980 - tn: 30827996.0000 - fn: 2897066.0000 - accuracy: 0.9133 - precision: 0.1063 - recall: 0.0012 - auc: 0.5290 - val_loss: 0.5224 - val_tp: 3361.0000 - val_fp: 28138.0000 - val_tn: 31391692.0000 - val_fn: 2949194.2500 - val_accuracy: 0.9134 - val_precision: 0.1067 - val_recall: 0.0011 - val_auc: 0.5294
# Epoch 27/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2384 - tp: 3371.3796 - fp: 28172.5820 - tn: 31953742.0000 - fn: 3003150.7500 - accuracy: 0.9134 - precision: 0.1069 - recall: 0.0011 - auc: 0.5301 - val_loss: 0.5197 - val_tp: 3389.0000 - val_fp: 28211.0000 - val_tn: 32517316.0000 - val_fn: 3055404.0000 - val_accuracy: 0.9134 - val_precision: 0.1072 - val_recall: 0.0011 - val_auc: 0.5305
# Epoch 28/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2385 - tp: 3413.1660 - fp: 28261.7988 - tn: 33079162.0000 - fn: 3109527.7500 - accuracy: 0.9134 - precision: 0.1078 - recall: 0.0011 - auc: 0.5311 - val_loss: 0.5224 - val_tp: 3433.0000 - val_fp: 28310.0000 - val_tn: 33642880.0000 - val_fn: 3161599.0000 - val_accuracy: 0.9134 - val_precision: 0.1081 - val_recall: 0.0011 - val_auc: 0.5315
# Epoch 29/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2384 - tp: 3447.4980 - fp: 28353.6406 - tn: 34204776.0000 - fn: 3215668.0000 - accuracy: 0.9134 - precision: 0.1084 - recall: 0.0011 - auc: 0.5320 - val_loss: 0.5211 - val_tp: 3464.0000 - val_fp: 28395.0000 - val_tn: 34768444.0000 - val_fn: 3267806.2500 - val_accuracy: 0.9134 - val_precision: 0.1087 - val_recall: 0.0011 - val_auc: 0.5324
# Epoch 30/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2384 - tp: 3487.7385 - fp: 28436.8457 - tn: 35330288.0000 - fn: 3321967.0000 - accuracy: 0.9134 - precision: 0.1092 - recall: 0.0010 - auc: 0.5329 - val_loss: 0.5217 - val_tp: 3511.0000 - val_fp: 28484.0000 - val_tn: 35894012.0000 - val_fn: 3373996.0000 - val_accuracy: 0.9134 - val_precision: 0.1097 - val_recall: 0.0010 - val_auc: 0.5333
# Epoch 31/100
#  - ETA: 4s - loss: 0.2396 - tp: 3512.9558 - fp: 28490.3672 - tn: 36059468.0000 - fn: 3400673.7500 - accuracy: 0.9132 - precision: 0.1098 - recall: 0.0010 - auc: 0.5334
# Epoch 32/100
#  - ETA: 0s - loss: 0.2385 - tp: 3576.1509 - fp: 28612.4297 - tn: 37557568.0000 - fn: 3532610.0000 - accuracy: 0.9134 - precision: 0.1111 - recall: 0.0010 - auc: 0.5344
# Epoch 33/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2383 - tp: 3626.6660 - fp: 28704.3027 - tn: 38706992.0000 - fn: 3640531.7500 - accuracy: 0.9134 - precision: 0.1122 - recall: 9.9520e-04 - auc: 0.5352 - val_loss: 0.5216 - val_tp: 3647.0000 - val_fp: 28745.0000 - val_tn: 39270792.0000 - val_fn: 3692575.0000 - val_accuracy: 0.9134 - val_precision: 0.1126 - val_recall: 9.8669e-04 - val_auc: 0.5354
# Epoch 34/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2384 - tp: 3675.4336 - fp: 28777.6465 - tn: 39832668.0000 - fn: 3746653.5000 - accuracy: 0.9134 - precision: 0.1133 - recall: 9.8003e-04 - auc: 0.5359 - val_loss: 0.5203 - val_tp: 3700.0000 - val_fp: 28808.0000 - val_tn: 40396332.0000 - val_fn: 3798756.2500 - val_accuracy: 0.9135 - val_precision: 0.1138 - val_recall: 9.7306e-04 - val_auc: 0.5362
# Epoch 35/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2383 - tp: 3730.8713 - fp: 28866.5059 - tn: 40958276.0000 - fn: 3852813.5000 - accuracy: 0.9134 - precision: 0.1145 - recall: 9.6742e-04 - auc: 0.5366 - val_loss: 0.5226 - val_tp: 3760.0000 - val_fp: 28912.0000 - val_tn: 41521924.0000 - val_fn: 3904936.7500 - val_accuracy: 0.9135 - val_precision: 0.1151 - val_recall: 9.6197e-04 - val_auc: 0.5369
# Epoch 36/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2383 - tp: 3777.3257 - fp: 28955.7676 - tn: 42083720.0000 - fn: 3959176.2500 - accuracy: 0.9134 - precision: 0.1154 - recall: 9.5317e-04 - auc: 0.5372 - val_loss: 0.5217 - val_tp: 3796.0000 - val_fp: 28997.0000 - val_tn: 42647544.0000 - val_fn: 4011138.0000 - val_accuracy: 0.9135 - val_precision: 0.1158 - val_recall: 9.4548e-04 - val_auc: 0.5375
# Epoch 37/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2384 - tp: 3804.9897 - fp: 29032.1738 - tn: 43209444.0000 - fn: 4065271.2500 - accuracy: 0.9134 - precision: 0.1159 - recall: 9.3511e-04 - auc: 0.5378 - val_loss: 0.5243 - val_tp: 3820.0000 - val_fp: 29079.0000 - val_tn: 43773172.0000 - val_fn: 4117352.5000 - val_accuracy: 0.9135 - val_precision: 0.1161 - val_recall: 9.2693e-04 - val_auc: 0.5379
# Epoch 38/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2383 - tp: 3841.5227 - fp: 29124.3613 - tn: 44334976.0000 - fn: 4171519.0000 - accuracy: 0.9135 - precision: 0.1165 - recall: 9.2005e-04 - auc: 0.5381 - val_loss: 0.5221 - val_tp: 3865.0000 - val_fp: 29168.0000 - val_tn: 44898752.0000 - val_fn: 4223546.0000 - val_accuracy: 0.9135 - val_precision: 0.1170 - val_recall: 9.1428e-04 - val_auc: 0.5383
# Epoch 39/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2383 - tp: 3893.8257 - fp: 29205.8906 - tn: 45460700.0000 - fn: 4277565.5000 - accuracy: 0.9135 - precision: 0.1176 - recall: 9.0946e-04 - auc: 0.5387 - val_loss: 0.5223 - val_tp: 3918.0000 - val_fp: 29241.0000 - val_tn: 46024344.0000 - val_fn: 4329730.5000 - val_accuracy: 0.9135 - val_precision: 0.1182 - val_recall: 9.0409e-04 - val_auc: 0.5388
# Epoch 40/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2382 - tp: 3953.6016 - fp: 29283.5000 - tn: 46586140.0000 - fn: 4383901.0000 - accuracy: 0.9135 - precision: 0.1190 - recall: 9.0103e-04 - auc: 0.5391 - val_loss: 0.5239 - val_tp: 3978.0000 - val_fp: 29318.0000 - val_tn: 47149968.0000 - val_fn: 4435908.5000 - val_accuracy: 0.9135 - val_precision: 0.1195 - val_recall: 8.9598e-04 - val_auc: 0.5392
# Epoch 41/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2383 - tp: 3991.8838 - fp: 29360.3672 - tn: 47711808.0000 - fn: 4490029.5000 - accuracy: 0.9135 - precision: 0.1197 - recall: 8.8827e-04 - auc: 0.5395 - val_loss: 0.5217 - val_tp: 4010.0000 - val_fp: 29399.0000 - val_tn: 48275576.0000 - val_fn: 4542115.0000 - val_accuracy: 0.9135 - val_precision: 0.1200 - val_recall: 8.8208e-04 - val_auc: 0.5396
# Epoch 42/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2383 - tp: 4026.7676 - fp: 29448.2051 - tn: 48837360.0000 - fn: 4596293.5000 - accuracy: 0.9135 - precision: 0.1203 - recall: 8.7533e-04 - auc: 0.5399 - val_loss: 0.5232 - val_tp: 4043.0000 - val_fp: 29495.0000 - val_tn: 49401140.0000 - val_fn: 4648318.0000 - val_accuracy: 0.9135 - val_precision: 0.1205 - val_recall: 8.6903e-04 - val_auc: 0.5401
# Epoch 43/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2382 - tp: 4066.4419 - fp: 29544.2070 - tn: 49962940.0000 - fn: 4702473.5000 - accuracy: 0.9135 - precision: 0.1210 - recall: 8.6400e-04 - auc: 0.5403 - val_loss: 0.5228 - val_tp: 4092.0000 - val_fp: 29592.0000 - val_tn: 50526680.0000 - val_fn: 4754511.5000 - val_accuracy: 0.9135 - val_precision: 0.1215 - val_recall: 8.5992e-04 - val_auc: 0.5404
# Epoch 44/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2382 - tp: 4117.0000 - fp: 29640.0723 - tn: 51088608.0000 - fn: 4808583.5000 - accuracy: 0.9135 - precision: 0.1220 - recall: 8.5545e-04 - auc: 0.5407 - val_loss: 0.5211 - val_tp: 4141.0000 - val_fp: 29685.0000 - val_tn: 51652236.0000 - val_fn: 4860698.0000 - val_accuracy: 0.9135 - val_precision: 0.1224 - val_recall: 8.5122e-04 - val_auc: 0.5409
# Epoch 45/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2383 - tp: 4161.0454 - fp: 29741.5762 - tn: 52214164.0000 - fn: 4914734.5000 - accuracy: 0.9135 - precision: 0.1227 - recall: 8.4594e-04 - auc: 0.5412 - val_loss: 0.5196 - val_tp: 4175.0000 - val_fp: 29786.0000 - val_tn: 52777808.0000 - val_fn: 4966903.0000 - val_accuracy: 0.9135 - val_precision: 0.1229 - val_recall: 8.3986e-04 - val_auc: 0.5414
# Epoch 46/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2382 - tp: 4203.7344 - fp: 29827.3711 - tn: 53339548.0000 - fn: 5021126.0000 - accuracy: 0.9135 - precision: 0.1235 - recall: 8.3651e-04 - auc: 0.5417 - val_loss: 0.5213 - val_tp: 4231.0000 - val_fp: 29871.0000 - val_tn: 53903356.0000 - val_fn: 5073081.0000 - val_accuracy: 0.9135 - val_precision: 0.1241 - val_recall: 8.3332e-04 - val_auc: 0.5418
# Epoch 47/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2382 - tp: 4256.3755 - fp: 29910.5254 - tn: 54465288.0000 - fn: 5127144.5000 - accuracy: 0.9135 - precision: 0.1246 - recall: 8.2948e-04 - auc: 0.5420 - val_loss: 0.5206 - val_tp: 4279.0000 - val_fp: 29949.0000 - val_tn: 55028980.0000 - val_fn: 5179276.5000 - val_accuracy: 0.9135 - val_precision: 0.1250 - val_recall: 8.2550e-04 - val_auc: 0.5422
# Epoch 48/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 4299.3359 - fp: 29993.5625 - tn: 55590708.0000 - fn: 5233485.0000 - accuracy: 0.9135 - precision: 0.1254 - recall: 8.2083e-04 - auc: 0.5425 - val_loss: 0.5230 - val_tp: 4313.0000 - val_fp: 30037.0000 - val_tn: 56154536.0000 - val_fn: 5285477.0000 - val_accuracy: 0.9135 - val_precision: 0.1256 - val_recall: 8.1535e-04 - val_auc: 0.5426
# Epoch 49/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 4326.6226 - fp: 30067.1914 - tn: 56716404.0000 - fn: 5339629.5000 - accuracy: 0.9135 - precision: 0.1258 - recall: 8.0963e-04 - auc: 0.5428 - val_loss: 0.5214 - val_tp: 4343.0000 - val_fp: 30103.0000 - val_tn: 57280140.0000 - val_fn: 5391689.0000 - val_accuracy: 0.9135 - val_precision: 0.1261 - val_recall: 8.0486e-04 - val_auc: 0.5430
# Epoch 50/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 4376.1616 - fp: 30153.9863 - tn: 57842060.0000 - fn: 5445754.0000 - accuracy: 0.9135 - precision: 0.1267 - recall: 8.0294e-04 - auc: 0.5432 - val_loss: 0.5192 - val_tp: 4403.0000 - val_fp: 30204.0000 - val_tn: 58405776.0000 - val_fn: 5497867.0000 - val_accuracy: 0.9135 - val_precision: 0.1272 - val_recall: 8.0022e-04 - val_auc: 0.5434
# Epoch 51/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2383 - tp: 4415.3193 - fp: 30237.3965 - tn: 58967732.0000 - fn: 5551891.5000 - accuracy: 0.9135 - precision: 0.1274 - recall: 7.9465e-04 - auc: 0.5436 - val_loss: 0.5225 - val_tp: 4431.0000 - val_fp: 30276.0000 - val_tn: 59531320.0000 - val_fn: 5604072.0000 - val_accuracy: 0.9135 - val_precision: 0.1277 - val_recall: 7.9005e-04 - val_auc: 0.5436
# Epoch 52/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 4449.8403 - fp: 30323.2051 - tn: 60093172.0000 - fn: 5658249.5000 - accuracy: 0.9135 - precision: 0.1280 - recall: 7.8582e-04 - auc: 0.5438 - val_loss: 0.5209 - val_tp: 4468.0000 - val_fp: 30366.0000 - val_tn: 60656956.0000 - val_fn: 5710273.5000 - val_accuracy: 0.9135 - val_precision: 0.1283 - val_recall: 7.8184e-04 - val_auc: 0.5439
# Epoch 53/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 4484.2261 - fp: 30400.4023 - tn: 61218832.0000 - fn: 5764371.0000 - accuracy: 0.9135 - precision: 0.1285 - recall: 7.7732e-04 - auc: 0.5441 - val_loss: 0.5233 - val_tp: 4511.0000 - val_fp: 30442.0000 - val_tn: 61782548.0000 - val_fn: 5816472.5000 - val_accuracy: 0.9135 - val_precision: 0.1291 - val_recall: 7.7496e-04 - val_auc: 0.5441
# Epoch 54/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 4533.9521 - fp: 30481.8770 - tn: 62344396.0000 - fn: 5870627.0000 - accuracy: 0.9135 - precision: 0.1295 - recall: 7.7172e-04 - auc: 0.5442 - val_loss: 0.5221 - val_tp: 4560.0000 - val_fp: 30527.0000 - val_tn: 62908172.0000 - val_fn: 5922658.5000 - val_accuracy: 0.9136 - val_precision: 0.1300 - val_recall: 7.6934e-04 - val_auc: 0.5443
# Epoch 55/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2382 - tp: 4589.6724 - fp: 30580.3672 - tn: 63470040.0000 - fn: 5976713.0000 - accuracy: 0.9135 - precision: 0.1305 - recall: 7.6734e-04 - auc: 0.5445 - val_loss: 0.5221 - val_tp: 4614.0000 - val_fp: 30637.0000 - val_tn: 64033680.0000 - val_fn: 6028842.5000 - val_accuracy: 0.9136 - val_precision: 0.1309 - val_recall: 7.6474e-04 - val_auc: 0.5445
# Epoch 56/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2382 - tp: 4637.5620 - fp: 30686.0098 - tn: 64595588.0000 - fn: 6082941.5000 - accuracy: 0.9135 - precision: 0.1313 - recall: 7.6181e-04 - auc: 0.5447 - val_loss: 0.5215 - val_tp: 4649.0000 - val_fp: 30722.0000 - val_tn: 65159292.0000 - val_fn: 6135052.0000 - val_accuracy: 0.9136 - val_precision: 0.1314 - val_recall: 7.5721e-04 - val_auc: 0.5448
# Epoch 57/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2382 - tp: 4669.6016 - fp: 30755.0742 - tn: 65721132.0000 - fn: 6189251.5000 - accuracy: 0.9135 - precision: 0.1318 - recall: 7.5390e-04 - auc: 0.5449 - val_loss: 0.5219 - val_tp: 4695.0000 - val_fp: 30801.0000 - val_tn: 66284936.0000 - val_fn: 6241241.0000 - val_accuracy: 0.9136 - val_precision: 0.1323 - val_recall: 7.5169e-04 - val_auc: 0.5450
# Epoch 58/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2382 - tp: 4721.3403 - fp: 30844.3027 - tn: 66846788.0000 - fn: 6295379.5000 - accuracy: 0.9135 - precision: 0.1327 - recall: 7.4941e-04 - auc: 0.5451 - val_loss: 0.5220 - val_tp: 4743.0000 - val_fp: 30896.0000 - val_tn: 67410528.0000 - val_fn: 6347428.5000 - val_accuracy: 0.9136 - val_precision: 0.1331 - val_recall: 7.4668e-04 - val_auc: 0.5452
# Epoch 59/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 4758.8921 - fp: 30931.0195 - tn: 67972464.0000 - fn: 6401466.0000 - accuracy: 0.9136 - precision: 0.1333 - recall: 7.4286e-04 - auc: 0.5454 - val_loss: 0.5226 - val_tp: 4780.0000 - val_fp: 30966.0000 - val_tn: 68536136.0000 - val_fn: 6453628.0000 - val_accuracy: 0.9136 - val_precision: 0.1337 - val_recall: 7.4012e-04 - val_auc: 0.5453
# Epoch 60/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 4803.1616 - fp: 31009.7070 - tn: 69098048.0000 - fn: 6507677.0000 - accuracy: 0.9136 - precision: 0.1341 - recall: 7.3753e-04 - auc: 0.5455 - val_loss: 0.5225 - val_tp: 4820.0000 - val_fp: 31050.0000 - val_tn: 69661736.0000 - val_fn: 6559829.5000 - val_accuracy: 0.9136 - val_precision: 0.1344 - val_recall: 7.3424e-04 - val_auc: 0.5455
# Epoch 61/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 4843.7695 - fp: 31085.4062 - tn: 70223504.0000 - fn: 6614010.5000 - accuracy: 0.9136 - precision: 0.1348 - recall: 7.3181e-04 - auc: 0.5456 - val_loss: 0.5205 - val_tp: 4869.0000 - val_fp: 31126.0000 - val_tn: 70787176.0000 - val_fn: 6666014.5000 - val_accuracy: 0.9136 - val_precision: 0.1353 - val_recall: 7.2989e-04 - val_auc: 0.5457
# Epoch 62/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 4892.1782 - fp: 31165.5547 - tn: 71349064.0000 - fn: 6720123.0000 - accuracy: 0.9136 - precision: 0.1357 - recall: 7.2746e-04 - auc: 0.5458 - val_loss: 0.5198 - val_tp: 4917.0000 - val_fp: 31207.0000 - val_tn: 71912776.0000 - val_fn: 6772202.5000 - val_accuracy: 0.9136 - val_precision: 0.1361 - val_recall: 7.2553e-04 - val_auc: 0.5460
# Epoch 63/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 4936.1494 - fp: 31248.5137 - tn: 72474680.0000 - fn: 6826277.0000 - accuracy: 0.9136 - precision: 0.1364 - recall: 7.2259e-04 - auc: 0.5462 - val_loss: 0.5226 - val_tp: 4960.0000 - val_fp: 31293.0000 - val_tn: 73038368.0000 - val_fn: 6878400.0000 - val_accuracy: 0.9136 - val_precision: 0.1368 - val_recall: 7.2058e-04 - val_auc: 0.5462
# Epoch 64/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2381 - tp: 4971.5728 - fp: 31329.8438 - tn: 73600176.0000 - fn: 6932523.5000 - accuracy: 0.9136 - precision: 0.1370 - recall: 7.1662e-04 - auc: 0.5463 - val_loss: 0.5217 - val_tp: 4993.0000 - val_fp: 31360.0000 - val_tn: 74163824.0000 - val_fn: 6984607.0000 - val_accuracy: 0.9136 - val_precision: 0.1373 - val_recall: 7.1435e-04 - val_auc: 0.5464
# Epoch 65/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2382 - tp: 5016.1118 - fp: 31405.8672 - tn: 74725744.0000 - fn: 7038685.5000 - accuracy: 0.9136 - precision: 0.1377 - recall: 7.1214e-04 - auc: 0.5466 - val_loss: 0.5206 - val_tp: 5042.0000 - val_fp: 31451.0000 - val_tn: 75289416.0000 - val_fn: 7090794.0000 - val_accuracy: 0.9136 - val_precision: 0.1382 - val_recall: 7.1056e-04 - val_auc: 0.5466
# Epoch 66/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2381 - tp: 5062.1367 - fp: 31487.5020 - tn: 75851304.0000 - fn: 7144911.0000 - accuracy: 0.9136 - precision: 0.1385 - recall: 7.0799e-04 - auc: 0.5468 - val_loss: 0.5229 - val_tp: 5085.0000 - val_fp: 31522.0000 - val_tn: 76415000.0000 - val_fn: 7196988.5000 - val_accuracy: 0.9136 - val_precision: 0.1389 - val_recall: 7.0605e-04 - val_auc: 0.5468
# Epoch 67/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2381 - tp: 5104.3901 - fp: 31566.2461 - tn: 76976784.0000 - fn: 7251195.0000 - accuracy: 0.9136 - precision: 0.1392 - recall: 7.0344e-04 - auc: 0.5469 - val_loss: 0.5237 - val_tp: 5124.0000 - val_fp: 31603.0000 - val_tn: 77540648.0000 - val_fn: 7303188.5000 - val_accuracy: 0.9136 - val_precision: 0.1395 - val_recall: 7.0112e-04 - val_auc: 0.5470
# Epoch 68/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5150.0933 - fp: 31650.4277 - tn: 78102440.0000 - fn: 7357318.5000 - accuracy: 0.9136 - precision: 0.1399 - recall: 6.9951e-04 - auc: 0.5470 - val_loss: 0.5223 - val_tp: 5174.0000 - val_fp: 31688.0000 - val_tn: 78666184.0000 - val_fn: 7409378.5000 - val_accuracy: 0.9136 - val_precision: 0.1404 - val_recall: 6.9782e-04 - val_auc: 0.5471
# Epoch 69/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5196.1079 - fp: 31734.3594 - tn: 79228024.0000 - fn: 7463586.0000 - accuracy: 0.9136 - precision: 0.1407 - recall: 6.9571e-04 - auc: 0.5472 - val_loss: 0.5236 - val_tp: 5224.0000 - val_fp: 31784.0000 - val_tn: 79791808.0000 - val_fn: 7515562.5000 - val_accuracy: 0.9136 - val_precision: 0.1412 - val_recall: 6.9461e-04 - val_auc: 0.5472
# Epoch 70/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5245.7305 - fp: 31831.6855 - tn: 80353752.0000 - fn: 7569639.5000 - accuracy: 0.9136 - precision: 0.1415 - recall: 6.9252e-04 - auc: 0.5473 - val_loss: 0.5213 - val_tp: 5265.0000 - val_fp: 31875.0000 - val_tn: 80917392.0000 - val_fn: 7621760.5000 - val_accuracy: 0.9136 - val_precision: 0.1418 - val_recall: 6.9031e-04 - val_auc: 0.5473
# Epoch 71/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5283.6533 - fp: 31915.9277 - tn: 81479376.0000 - fn: 7675816.0000 - accuracy: 0.9136 - precision: 0.1420 - recall: 6.8788e-04 - auc: 0.5474 - val_loss: 0.5208 - val_tp: 5300.0000 - val_fp: 31961.0000 - val_tn: 82043024.0000 - val_fn: 7727968.5000 - val_accuracy: 0.9136 - val_precision: 0.1422 - val_recall: 6.8535e-04 - val_auc: 0.5475
# Epoch 72/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5315.8506 - fp: 31998.7676 - tn: 82604960.0000 - fn: 7782048.5000 - accuracy: 0.9136 - precision: 0.1425 - recall: 6.8263e-04 - auc: 0.5477 - val_loss: 0.5228 - val_tp: 5331.0000 - val_fp: 32034.0000 - val_tn: 83168656.0000 - val_fn: 7834171.0000 - val_accuracy: 0.9136 - val_precision: 0.1427 - val_recall: 6.8002e-04 - val_auc: 0.5476
# Epoch 73/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2381 - tp: 5355.7969 - fp: 32084.6582 - tn: 83730544.0000 - fn: 7888219.0000 - accuracy: 0.9136 - precision: 0.1430 - recall: 6.7850e-04 - auc: 0.5477 - val_loss: 0.5203 - val_tp: 5372.0000 - val_fp: 32130.0000 - val_tn: 84294176.0000 - val_fn: 7940368.0000 - val_accuracy: 0.9136 - val_precision: 0.1432 - val_recall: 6.7609e-04 - val_auc: 0.5477
# Epoch 74/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5389.6309 - fp: 32159.9570 - tn: 84856048.0000 - fn: 7994455.0000 - accuracy: 0.9136 - precision: 0.1435 - recall: 6.7372e-04 - auc: 0.5479 - val_loss: 0.5204 - val_tp: 5417.0000 - val_fp: 32205.0000 - val_tn: 85419712.0000 - val_fn: 8046565.0000 - val_accuracy: 0.9136 - val_precision: 0.1440 - val_recall: 6.7276e-04 - val_auc: 0.5479
# Epoch 75/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5437.0518 - fp: 32239.1309 - tn: 85981640.0000 - fn: 8100637.5000 - accuracy: 0.9136 - precision: 0.1443 - recall: 6.7074e-04 - auc: 0.5481 - val_loss: 0.5205 - val_tp: 5456.0000 - val_fp: 32280.0000 - val_tn: 86545288.0000 - val_fn: 8152762.5000 - val_accuracy: 0.9136 - val_precision: 0.1446 - val_recall: 6.6877e-04 - val_auc: 0.5481
# Epoch 76/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5472.7388 - fp: 32317.4473 - tn: 87107224.0000 - fn: 8206814.0000 - accuracy: 0.9136 - precision: 0.1448 - recall: 6.6641e-04 - auc: 0.5483 - val_loss: 0.5197 - val_tp: 5498.0000 - val_fp: 32360.0000 - val_tn: 87670872.0000 - val_fn: 8258959.0000 - val_accuracy: 0.9136 - val_precision: 0.1452 - val_recall: 6.6526e-04 - val_auc: 0.5483
# Epoch 77/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5511.6411 - fp: 32401.4277 - tn: 88232744.0000 - fn: 8313080.0000 - accuracy: 0.9136 - precision: 0.1454 - recall: 6.6257e-04 - auc: 0.5484 - val_loss: 0.5230 - val_tp: 5527.0000 - val_fp: 32440.0000 - val_tn: 88796520.0000 - val_fn: 8365161.5000 - val_accuracy: 0.9136 - val_precision: 0.1456 - val_recall: 6.6028e-04 - val_auc: 0.5484
# Epoch 78/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5547.4897 - fp: 32477.8633 - tn: 89358424.0000 - fn: 8419216.0000 - accuracy: 0.9136 - precision: 0.1459 - recall: 6.5847e-04 - auc: 0.5485 - val_loss: 0.5217 - val_tp: 5564.0000 - val_fp: 32520.0000 - val_tn: 89922016.0000 - val_fn: 8471373.0000 - val_accuracy: 0.9136 - val_precision: 0.1461 - val_recall: 6.5637e-04 - val_auc: 0.5485
# Epoch 79/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5578.5664 - fp: 32554.4844 - tn: 90484000.0000 - fn: 8525425.0000 - accuracy: 0.9136 - precision: 0.1463 - recall: 6.5392e-04 - auc: 0.5485 - val_loss: 0.5209 - val_tp: 5592.0000 - val_fp: 32592.0000 - val_tn: 91047616.0000 - val_fn: 8577576.0000 - val_accuracy: 0.9136 - val_precision: 0.1464 - val_recall: 6.5151e-04 - val_auc: 0.5486
# Epoch 80/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5610.7095 - fp: 32628.9785 - tn: 91609496.0000 - fn: 8631733.0000 - accuracy: 0.9136 - precision: 0.1467 - recall: 6.4959e-04 - auc: 0.5487 - val_loss: 0.5228 - val_tp: 5633.0000 - val_fp: 32662.0000 - val_tn: 92173168.0000 - val_fn: 8683774.0000 - val_accuracy: 0.9136 - val_precision: 0.1471 - val_recall: 6.4826e-04 - val_auc: 0.5487
# Epoch 81/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5661.1035 - fp: 32705.4219 - tn: 92734952.0000 - fn: 8737984.0000 - accuracy: 0.9136 - precision: 0.1476 - recall: 6.4745e-04 - auc: 0.5487 - val_loss: 0.5244 - val_tp: 5689.0000 - val_fp: 32753.0000 - val_tn: 93298864.0000 - val_fn: 8789958.0000 - val_accuracy: 0.9136 - val_precision: 0.1480 - val_recall: 6.4680e-04 - val_auc: 0.5487
# Epoch 82/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5712.0122 - fp: 32797.2812 - tn: 93860536.0000 - fn: 8844155.0000 - accuracy: 0.9136 - precision: 0.1483 - recall: 6.4543e-04 - auc: 0.5488 - val_loss: 0.5226 - val_tp: 5729.0000 - val_fp: 32835.0000 - val_tn: 94424408.0000 - val_fn: 8896153.0000 - val_accuracy: 0.9136 - val_precision: 0.1486 - val_recall: 6.4357e-04 - val_auc: 0.5487
# Epoch 83/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.2382 - tp: 5747.5288 - fp: 32875.6719 - tn: 94986216.0000 - fn: 8950269.0000 - accuracy: 0.9136 - precision: 0.1488 - recall: 6.4175e-04 - auc: 0.5488 - val_loss: 0.5219 - val_tp: 5760.0000 - val_fp: 32920.0000 - val_tn: 95549848.0000 - val_fn: 9002365.0000 - val_accuracy: 0.9136 - val_precision: 0.1489 - val_recall: 6.3942e-04 - val_auc: 0.5488
# Epoch 84/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5782.2739 - fp: 32963.0195 - tn: 96111688.0000 - fn: 9056562.0000 - accuracy: 0.9136 - precision: 0.1492 - recall: 6.3805e-04 - auc: 0.5488 - val_loss: 0.5239 - val_tp: 5806.0000 - val_fp: 33012.0000 - val_tn: 96675424.0000 - val_fn: 9108556.0000 - val_accuracy: 0.9136 - val_precision: 0.1496 - val_recall: 6.3702e-04 - val_auc: 0.5488
# Epoch 85/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5830.2861 - fp: 33056.6367 - tn: 97237288.0000 - fn: 9162712.0000 - accuracy: 0.9136 - precision: 0.1499 - recall: 6.3590e-04 - auc: 0.5488 - val_loss: 0.5229 - val_tp: 5858.0000 - val_fp: 33104.0000 - val_tn: 97800928.0000 - val_fn: 9214737.0000 - val_accuracy: 0.9136 - val_precision: 0.1504 - val_recall: 6.3532e-04 - val_auc: 0.5488
# Epoch 86/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2383 - tp: 5875.7861 - fp: 33149.7656 - tn: 98362760.0000 - fn: 9268939.0000 - accuracy: 0.9136 - precision: 0.1506 - recall: 6.3352e-04 - auc: 0.5488 - val_loss: 0.5216 - val_tp: 5896.0000 - val_fp: 33189.0000 - val_tn: 98926704.0000 - val_fn: 9320940.0000 - val_accuracy: 0.9136 - val_precision: 0.1509 - val_recall: 6.3216e-04 - val_auc: 0.5488
# Epoch 87/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 5920.8857 - fp: 33238.3359 - tn: 99488552.0000 - fn: 9374971.0000 - accuracy: 0.9136 - precision: 0.1512 - recall: 6.3116e-04 - auc: 0.5489 - val_loss: 0.5235 - val_tp: 5945.0000 - val_fp: 33285.0000 - val_tn: 100052192.0000 - val_fn: 9427131.0000 - val_accuracy: 0.9136 - val_precision: 0.1515 - val_recall: 6.3023e-04 - val_auc: 0.5488
# Epoch 88/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 5976.1909 - fp: 33336.5312 - tn: 100613912.0000 - fn: 9481325.0000 - accuracy: 0.9136 - precision: 0.1520 - recall: 6.2991e-04 - auc: 0.5489 - val_loss: 0.5232 - val_tp: 6000.0000 - val_fp: 33391.0000 - val_tn: 101177696.0000 - val_fn: 9533313.0000 - val_accuracy: 0.9136 - val_precision: 0.1523 - val_recall: 6.2898e-04 - val_auc: 0.5489
# Epoch 89/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 6019.8237 - fp: 33424.6680 - tn: 101739592.0000 - fn: 9587327.0000 - accuracy: 0.9136 - precision: 0.1526 - recall: 6.2750e-04 - auc: 0.5489 - val_loss: 0.5196 - val_tp: 6044.0000 - val_fp: 33459.0000 - val_tn: 102303264.0000 - val_fn: 9639501.0000 - val_accuracy: 0.9136 - val_precision: 0.1530 - val_recall: 6.2661e-04 - val_auc: 0.5490
# Epoch 90/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 6068.3340 - fp: 33498.5859 - tn: 102865112.0000 - fn: 9693640.0000 - accuracy: 0.9136 - precision: 0.1534 - recall: 6.2562e-04 - auc: 0.5491 - val_loss: 0.5210 - val_tp: 6092.0000 - val_fp: 33541.0000 - val_tn: 103428744.0000 - val_fn: 9745696.0000 - val_accuracy: 0.9136 - val_precision: 0.1537 - val_recall: 6.2471e-04 - val_auc: 0.5491
# Epoch 91/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 6120.0645 - fp: 33585.3047 - tn: 103990760.0000 - fn: 9799730.0000 - accuracy: 0.9136 - precision: 0.1541 - recall: 6.2412e-04 - auc: 0.5492 - val_loss: 0.5223 - val_tp: 6149.0000 - val_fp: 33639.0000 - val_tn: 104554312.0000 - val_fn: 9851881.0000 - val_accuracy: 0.9136 - val_precision: 0.1545 - val_recall: 6.2376e-04 - val_auc: 0.5491
# Epoch 92/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 6170.3818 - fp: 33681.3164 - tn: 105116152.0000 - fn: 9906040.0000 - accuracy: 0.9136 - precision: 0.1548 - recall: 6.2250e-04 - auc: 0.5492 - val_loss: 0.5256 - val_tp: 6193.0000 - val_fp: 33723.0000 - val_tn: 105679992.0000 - val_fn: 9958068.0000 - val_accuracy: 0.9136 - val_precision: 0.1552 - val_recall: 6.2152e-04 - val_auc: 0.5491
# Epoch 93/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2381 - tp: 6222.3091 - fp: 33779.2266 - tn: 106241688.0000 - fn: 10012212.0000 - accuracy: 0.9136 - precision: 0.1556 - recall: 6.2109e-04 - auc: 0.5492 - val_loss: 0.5229 - val_tp: 6247.0000 - val_fp: 33825.0000 - val_tn: 106805504.0000 - val_fn: 10064261.0000 - val_accuracy: 0.9136 - val_precision: 0.1559 - val_recall: 6.2033e-04 - val_auc: 0.5491
# Epoch 94/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.2382 - tp: 6268.6948 - fp: 33865.9453 - tn: 107367264.0000 - fn: 10118413.0000 - accuracy: 0.9136 - precision: 0.1562 - recall: 6.1915e-04 - auc: 0.5492 - val_loss: 0.5232 - val_tp: 6298.0000 - val_fp: 33910.0000 - val_tn: 107931024.0000 - val_fn: 10170438.0000 - val_accuracy: 0.9136 - val_precision: 0.1566 - val_recall: 6.1886e-04 - val_auc: 0.5491
# Epoch 95/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2381 - tp: 6325.4004 - fp: 33952.8867 - tn: 108492792.0000 - fn: 10224612.0000 - accuracy: 0.9136 - precision: 0.1570 - recall: 6.1826e-04 - auc: 0.5492 - val_loss: 0.5220 - val_tp: 6342.0000 - val_fp: 33994.0000 - val_tn: 109056504.0000 - val_fn: 10276637.0000 - val_accuracy: 0.9136 - val_precision: 0.1572 - val_recall: 6.1675e-04 - val_auc: 0.5491
# Epoch 96/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2381 - tp: 6357.2778 - fp: 34026.2461 - tn: 109618360.0000 - fn: 10330762.0000 - accuracy: 0.9136 - precision: 0.1574 - recall: 6.1500e-04 - auc: 0.5492 - val_loss: 0.5239 - val_tp: 6375.0000 - val_fp: 34067.0000 - val_tn: 110182008.0000 - val_fn: 10382849.0000 - val_accuracy: 0.9136 - val_precision: 0.1576 - val_recall: 6.1362e-04 - val_auc: 0.5491
# Epoch 97/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2381 - tp: 6397.9937 - fp: 34108.9609 - tn: 110744104.0000 - fn: 10436798.0000 - accuracy: 0.9136 - precision: 0.1579 - recall: 6.1265e-04 - auc: 0.5492 - val_loss: 0.5207 - val_tp: 6419.0000 - val_fp: 34145.0000 - val_tn: 111307568.0000 - val_fn: 10489030.0000 - val_accuracy: 0.9136 - val_precision: 0.1582 - val_recall: 6.1160e-04 - val_auc: 0.5491
# Epoch 98/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2381 - tp: 6449.2056 - fp: 34196.2578 - tn: 111869520.0000 - fn: 10543151.0000 - accuracy: 0.9136 - precision: 0.1587 - recall: 6.1132e-04 - auc: 0.5492 - val_loss: 0.5202 - val_tp: 6474.0000 - val_fp: 34242.0000 - val_tn: 112433320.0000 - val_fn: 10595217.0000 - val_accuracy: 0.9136 - val_precision: 0.1590 - val_recall: 6.1066e-04 - val_auc: 0.5493
# Epoch 99/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2381 - tp: 6494.3818 - fp: 34281.2383 - tn: 112995072.0000 - fn: 10649339.0000 - accuracy: 0.9136 - precision: 0.1593 - recall: 6.0947e-04 - auc: 0.5494 - val_loss: 0.5205 - val_tp: 6510.0000 - val_fp: 34320.0000 - val_tn: 113558872.0000 - val_fn: 10701423.0000 - val_accuracy: 0.9136 - val_precision: 0.1594 - val_recall: 6.0796e-04 - val_auc: 0.5494
# Epoch 100/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2381 - tp: 6527.8569 - fp: 34365.4180 - tn: 114120832.0000 - fn: 10755397.0000 - accuracy: 0.9136 - precision: 0.1596 - recall: 6.0657e-04 - auc: 0.5494 - val_loss: 0.5224 - val_tp: 6543.0000 - val_fp: 34411.0000 - val_tn: 114684400.0000 - val_fn: 10807621.0000 - val_accuracy: 0.9136 - val_precision: 0.1598 - val_recall: 6.0504e-04 - val_auc: 0.5494

# %%
train_predictions_baseline = model_baseline.predict(X_train, batch_size=BATCH_SIZE)
test_predictions_baseline = model_baseline.predict(X_test, batch_size=BATCH_SIZE)

# %%
print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
model_weighted = keras.Sequential()
model_weighted.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model_weighted.add(keras.layers.Dropout(0.5))
model_weighted.add(keras.layers.Dense(16,activation='relu'))
model_weighted.add(keras.layers.Dropout(0.5))
model_weighted.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model_weighted.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model_weighted.summary()
print('Compiled NN...')

model_weighted.load_weights(initial_weights)
weighted_history = model_weighted.fit(X_train,
                             y_train,
                             batch_size=BATCH_SIZE,
                             epochs=EPOCHS,
                             callbacks = [early_stopping],
                             validation_split=0.2, # The class weights go here
                             class_weight=class_weight)
# Out:
# Weight for class 0: 0.54
# Weight for class 1: 6.81
# Built NN...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 16)                208
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.7937 - tp: 12024.6768 - fp: 111678.6562 - tn: 115169112.0000 - fn: 10856189.0000 - accuracy: 0.9130 - precision: 0.1102 - recall: 0.0011 - auc: 0.5486 - val_loss: 1.2820 - val_tp: 20489.1406 - val_fp: 225287.1406 - val_tn: 115619056.0000 - val_fn: 10899920.0000 - val_accuracy: 0.9122 - val_precision: 0.0834 - val_recall: 0.0019 - val_auc: 0.5481
# Epoch 2/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6962 - tp: 30122.0156 - fp: 350011.0000 - tn: 116056296.0000 - fn: 10944460.0000 - accuracy: 0.9113 - precision: 0.0797 - recall: 0.0027 - auc: 0.5477 - val_loss: 1.2358 - val_tp: 42112.0508 - val_fp: 484251.7812 - val_tn: 116485832.0000 - val_fn: 10984529.0000 - val_accuracy: 0.9104 - val_precision: 0.0800 - val_recall: 0.0038 - val_auc: 0.5472
# Epoch 3/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6823 - tp: 55575.6758 - fp: 620305.5000 - tn: 116911712.0000 - fn: 11025209.0000 - accuracy: 0.9094 - precision: 0.0824 - recall: 0.0050 - auc: 0.5468 - val_loss: 1.2189 - val_tp: 66176.8516 - val_fp: 748544.6250 - val_tn: 117347240.0000 - val_fn: 11066694.0000 - val_accuracy: 0.9086 - val_precision: 0.0812 - val_recall: 0.0059 - val_auc: 0.5463
# Epoch 4/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6740 - tp: 77026.7812 - fp: 870128.7500 - tn: 117787464.0000 - fn: 11110076.0000 - accuracy: 0.9077 - precision: 0.0814 - recall: 0.0069 - auc: 0.5459 - val_loss: 1.2085 - val_tp: 88345.5938 - val_fp: 992397.8125 - val_tn: 118229096.0000 - val_fn: 11150778.0000 - val_accuracy: 0.9069 - val_precision: 0.0817 - val_recall: 0.0079 - val_auc: 0.5455
# Epoch 5/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6675 - tp: 100885.1719 - fp: 1110412.0000 - tn: 118672912.0000 - fn: 11192427.0000 - accuracy: 0.9061 - precision: 0.0833 - recall: 0.0089 - auc: 0.5451 - val_loss: 1.1963 - val_tp: 111987.3438 - val_fp: 1227702.8750 - val_tn: 119119384.0000 - val_fn: 11233366.0000 - val_accuracy: 0.9054 - val_precision: 0.0836 - val_recall: 0.0099 - val_auc: 0.5446
# Epoch 6/100
# 985539/985539 [==============================] - 4s 5us/step - loss: 0.6623 - tp: 124336.7969 - fp: 1343361.0000 - tn: 119565768.0000 - fn: 11275099.0000 - accuracy: 0.9046 - precision: 0.0847 - recall: 0.0109 - auc: 0.5443 - val_loss: 1.1846 - val_tp: 135557.2188 - val_fp: 1459607.0000 - val_tn: 120013216.0000 - val_fn: 11316031.0000 - val_accuracy: 0.9039 - val_precision: 0.0850 - val_recall: 0.0118 - val_auc: 0.5439
# Epoch 7/100
# 985539/985539 [==============================] - 4s 4us/step - loss: 0.6578 - tp: 147889.1406 - fp: 1572800.8750 - tn: 120462016.0000 - fn: 11357827.0000 - accuracy: 0.9032 - precision: 0.0860 - recall: 0.0129 - auc: 0.5435 - val_loss: 1.1800 - val_tp: 158776.2031 - val_fp: 1683643.8750 - val_tn: 120914912.0000 - val_fn: 11399062.0000 - val_accuracy: 0.9025 - val_precision: 0.0862 - val_recall: 0.0137 - val_auc: 0.5431
# Epoch 8/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6546 - tp: 169988.5000 - fp: 1777755.2500 - tn: 121382776.0000 - fn: 11441984.0000 - accuracy: 0.9019 - precision: 0.0873 - recall: 0.0146 - auc: 0.5428 - val_loss: 1.1756 - val_tp: 179500.6562 - val_fp: 1866157.8750 - val_tn: 121858128.0000 - val_fn: 11484572.0000 - val_accuracy: 0.9014 - val_precision: 0.0877 - val_recall: 0.0154 - val_auc: 0.5423
# Epoch 9/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6522 - tp: 189338.6562 - fp: 1939262.7500 - tn: 122346888.0000 - fn: 11528870.0000 - accuracy: 0.9010 - precision: 0.0890 - recall: 0.0162 - auc: 0.5420 - val_loss: 1.1669 - val_tp: 197888.7656 - val_fp: 2010245.3750 - val_tn: 122839632.0000 - val_fn: 11572418.0000 - val_accuracy: 0.9006 - val_precision: 0.0896 - val_recall: 0.0168 - val_auc: 0.5416
# Epoch 10/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6506 - tp: 207099.9844 - fp: 2071413.3750 - tn: 123340392.0000 - fn: 11617296.0000 - accuracy: 0.9002 - precision: 0.0909 - recall: 0.0175 - auc: 0.5413 - val_loss: 1.1596 - val_tp: 214928.7656 - val_fp: 2131801.0000 - val_tn: 123843728.0000 - val_fn: 11661620.0000 - val_accuracy: 0.8999 - val_precision: 0.0916 - val_recall: 0.0181 - val_auc: 0.5409
# Epoch 11/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6492 - tp: 223677.9219 - fp: 2183113.2500 - tn: 124354296.0000 - fn: 11707028.0000 - accuracy: 0.8997 - precision: 0.0929 - recall: 0.0187 - auc: 0.5406 - val_loss: 1.1588 - val_tp: 230843.6406 - val_fp: 2231268.5000 - val_tn: 124869960.0000 - val_fn: 11751942.0000 - val_accuracy: 0.8995 - val_precision: 0.0938 - val_recall: 0.0193 - val_auc: 0.5403
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %%
plot_metrics(weighted_history)
plt.show()

# %%
train_predictions_weighted = model_weighted.predict(X_train, batch_size=BATCH_SIZE)
test_predictions_weighted = model_weighted.predict(X_test, batch_size=BATCH_SIZE)

# %%
weighted_results = model_weighted.evaluate(X_test, y_test,
                                           batch_size=BATCH_SIZE, verbose=0)
for name, value in zip(model_weighted.metrics_names, weighted_results):
  print(name, ': ', value)
print()

plot_cm(y_test, test_predictions_weighted)
# Out:
# loss :  0.5169567913087973
# tp :  234967.765625
# fp :  2240870.0
# tn :  125109808.0
# fn :  11775412.0
# accuracy :  0.8994198441505432
# precision :  0.09490436315536499
# recall :  0.019563714042305946
# auc :  0.5402999520301819
#
# Legitimate Transactions Detected (True Negatives):  299856
# Legitimate Transactions Incorrectly Detected (False Positives):  1304
# Fraudulent Transactions Missed (False Negatives):  6788
# Fraudulent Transactions Detected (True Positives):  4
# Total Fraudulent Transactions:  6792

# %%
plot_roc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')

plot_roc("Train Weighted", y_train, train_predictions_weighted, color=colors[1])
plot_roc("Test Weighted", y_test, test_predictions_weighted, color=colors[1], linestyle='--')


plt.legend(loc='lower right')
plt.show()
