# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
import os
import tempfile 


from sklearn import preprocessing
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score, classification_report
from collections import Counter

import tensorflow as tf
import keras


import warnings
warnings.filterwarnings("ignore")
colors = np.array(['#0101DF','#DF0101','#01DF01'])

rs = 42
def compute_metrics (y_te2,y_p,string):
    print('\n %s'%string)
    print('CONFUSION MATRIX')
    print(metrics.confusion_matrix(y_te2,y_p))
    print(classification_report(y_te2, y_p))
    print('\nROC CURVE: %2.2f'%roc_auc_score(y_te2,y_p))

def Ratio10(y,string):
    suma = Counter(y)[0]+Counter(y)[1]
    print('\n'+string)  
    print(Counter(y))
    print('0: %3.2f%%\n1: %3.2f%%' % (100*Counter(y)[0]/suma,100*Counter(y)[1]/suma))

def histo(data,var):
    fig=plt.figure()
    sns.countplot(var,data=data,palette=colors)
    plt.title('0/1 Distribution (0: No Stalling || 1: Stalling Event',fontsize=14)
    plt.show()
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('../../output/df_general.csv', sep=',')
split = 0.8
del dataset['No.']
del dataset['Protocol']
del dataset['ip_len']
del dataset['prebuffering']
del dataset['Time']

dataset = dataset.fillna(dataset.mean())
neg, pos = np.bincount(dataset['stalling_event'])

print(dataset.columns)
Ratio10(dataset['stalling_event'],'dataset[stalling_event]')
histo(dataset,'stalling_event')
# Out:
# Index(['∆t', 'pkt_len', 'tcp_hea_len', 'tcp_flag_ack', 'tcp_flag_cwr',
#        'tcp_flag_ecn', 'tcp_flag_urg', 'tcp_flag_psh', 'tcp_flag_rst',
#        'tcp_flag_syn', 'tcp_flag_fin', 'tcp_win_si2', 'delay', 'capture',
#        'stalling_event'],
#       dtype='object')
#
# dataset[stalling_event]
# Counter({0: 1426905, 1: 113031})
# 0: 92.66%
# 1: 7.34%

# %%
from random import randint
'''X_train = [None] * (len(dataset.columns)-1)
X_test = [None] * (len(dataset.columns)-1)'''

X_train = np.array([None]*12)
X_test = np.array([None]*12)
y_train = list()
y_test = list()

grouped = dataset.groupby(['delay','capture']) 
#print(grouped.mean())

for id, data in grouped:
    spl = int(data.shape[0] * split)
    restspl = int(data.shape[0] * (1-split))
    randnum = randint(0,restspl)
    
    X_train = np.vstack((X_train,data.values[randnum:randnum+spl,:-3]))
    X_test = np.vstack((X_test,data.values[0:randnum-1,:-3]))
    X_test = np.vstack((X_test,data.values[randnum+spl:,:-3]))
    
    y_train.extend(data.values[randnum:randnum+spl,-1])
    y_test.extend(data.values[0:randnum-1,-1])
    y_test.extend(data.values[randnum+spl:,-1])

X_train = X_train[1:]
X_test = X_test[1:]

X_train = pd.DataFrame(data=X_train,columns=dataset.columns[:-3])
X_test= pd.DataFrame(data=X_test,columns=dataset.columns[:-3])
del dataset['delay']
del dataset['capture']

# %%
mms = preprocessing.MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)

# %%
y_test = list(map(int,y_test))
y_train = list(map(int,y_train))
Ratio10(y_test,'y_test')
Ratio10(y_train,'y_train')
# Out:
# y_test
# Counter({0: 302986, 1: 4966})
# 0: 98.39%
# 1: 1.61%
#
# y_train
# Counter({0: 1123860, 1: 108064})
# 0: 91.23%
# 1: 8.77%

# %%
X_train = pd.DataFrame(data=X_train,columns=dataset.columns[:-3])
X_test= pd.DataFrame(data=X_test,columns=dataset.columns[:-3])
cw_train = compute_class_weight('balanced',
                                np.unique(y_train),
                                y_train)
cw_test = compute_class_weight('balanced',
                                np.unique(y_test),
                                y_test)

y_train = pd.DataFrame(data=y_train,columns=['y_train'])
y_test= pd.DataFrame(data=y_test,columns=['y_test'])

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.TrueNegatives(name='tn'),
    tf.keras.metrics.FalseNegatives(name='fn'),
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
]

EPOCHS = 100
BATCH_SIZE = 2048

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', 
                                                  verbose=1,
                                                  patience=10,
                                                  mode='max',
                                                  restore_best_weights=True)

# %%
n_features = X_train.shape[1]
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# 1231924/1231924 [==============================] - 5s 4us/step
# Loss: 0.5453

# %%
initial_bias = np.log([pos/neg])
print(initial_bias)
# Out:
# [-2.53560092]

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid',bias_initializer=keras.initializers.Constant(initial_bias)))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_10 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# 1231924/1231924 [==============================] - 5s 4us/step
# Loss: 0.3081

# %%
initial_weights = os.path.join(tempfile.mkdtemp(),'initial_weights')
model.save_weights(initial_weights)

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')

model.load_weights(initial_weights)
model.layers[-1].bias.assign([0.0])
zero_bias_history = model.fit(X_train,
                              y_train,
                              batch_size=BATCH_SIZE,
                              epochs=20,
                              validation_split=0.2, 
                              verbose=1)
# Out:
# Built NN...
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 16)                208
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.3344 - tp: 75951.1016 - fp: 778953.5000 - tn: 3054281.0000 - fn: 281174.5938 - accuracy: 0.7462 - precision: 0.0888 - recall: 0.2133 - auc: 0.5039 - val_loss: 0.5190 - val_tp: 76026.0000 - val_fp: 779799.8125 - val_tn: 3616291.7500 - val_fn: 334110.1562 - val_accuracy: 0.7682 - val_precision: 0.0888 - val_recall: 0.1855 - val_auc: 0.5031
# Epoch 2/20
#  - ETA: 1s - loss: 0.2800 - tp: 76037.7734 - fp: 779819.8750 - tn: 4055867.7500 - fn: 380515.1562 - accuracy: 0.7805 - precision: 0.0888 - recall: 0.1667 - auc: 0.5000
# Epoch 3/20
#  - ETA: 3s - loss: 0.2716 - tp: 76058.2656 - fp: 779852.8750 - tn: 5011460.5000 - fn: 476566.4062 - accuracy: 0.8019 - precision: 0.0889 - recall: 0.1377 - auc: 0.4993
# Epoch 4/20
#  - ETA: 5s - loss: 0.2674 - tp: 76071.0000 - fp: 779875.1875 - tn: 5992886.5000 - fn: 574455.1875 - accuracy: 0.8176 - precision: 0.0889 - recall: 0.1169 - auc: 0.4998
# Epoch 5/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2591 - tp: 76073.8438 - fp: 779874.8750 - tn: 7548668.0000 - fn: 713432.2500 - accuracy: 0.8361 - precision: 0.0889 - recall: 0.0964 - auc: 0.5032 - val_loss: 0.5113 - val_tp: 76074.0000 - val_fp: 779880.0000 - val_tn: 8111648.5000 - val_fn: 766318.2500 - val_accuracy: 0.8412 - val_precision: 0.0889 - val_recall: 0.0903 - val_auc: 0.5039
# Epoch 6/20
#  - ETA: 0s - loss: 0.2552 - tp: 76073.8750 - fp: 779874.8750 - tn: 8664934.0000 - fn: 820905.3750 - accuracy: 0.8451 - precision: 0.0889 - recall: 0.0848 - auc: 0.5044
# Epoch 7/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2521 - tp: 76073.8438 - fp: 779874.8750 - tn: 9796466.0000 - fn: 929484.4375 - accuracy: 0.8524 - precision: 0.0889 - recall: 0.0757 - auc: 0.5060 - val_loss: 0.5060 - val_tp: 76074.0000 - val_fp: 779880.0000 - val_tn: 10359374.0000 - val_fn: 982446.5625 - val_accuracy: 0.8555 - val_precision: 0.0889 - val_recall: 0.0719 - val_auc: 0.5067
# Epoch 8/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2495 - tp: 76073.8438 - fp: 779874.8750 - tn: 10920302.0000 - fn: 1037569.5000 - accuracy: 0.8581 - precision: 0.0889 - recall: 0.0683 - auc: 0.5074 - val_loss: 0.5084 - val_tp: 76074.0000 - val_fp: 779880.0000 - val_tn: 11483229.0000 - val_fn: 1090510.5000 - val_accuracy: 0.8607 - val_precision: 0.0889 - val_recall: 0.0652 - val_auc: 0.5081
# Epoch 9/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2476 - tp: 76073.8438 - fp: 779874.8750 - tn: 12044205.0000 - fn: 1145594.1250 - accuracy: 0.8629 - precision: 0.0889 - recall: 0.0623 - auc: 0.5088 - val_loss: 0.5094 - val_tp: 76074.0000 - val_fp: 779880.0000 - val_tn: 12607089.0000 - val_fn: 1198574.1250 - val_accuracy: 0.8651 - val_precision: 0.0889 - val_recall: 0.0597 - val_auc: 0.5094
# Epoch 10/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2460 - tp: 76073.8438 - fp: 779874.8750 - tn: 13167870.0000 - fn: 1253859.0000 - accuracy: 0.8669 - precision: 0.0889 - recall: 0.0572 - auc: 0.5101 - val_loss: 0.5108 - val_tp: 76074.0000 - val_fp: 779880.0000 - val_tn: 13730942.0000 - val_fn: 1306637.8750 - val_accuracy: 0.8687 - val_precision: 0.0889 - val_recall: 0.0550 - val_auc: 0.5108
# Epoch 11/20
# 985539/985539 [==============================] - 9s 9us/step - loss: 0.2452 - tp: 76073.8438 - fp: 779874.8750 - tn: 14291940.0000 - fn: 1361704.0000 - accuracy: 0.8703 - precision: 0.0889 - recall: 0.0529 - auc: 0.5115 - val_loss: 0.5109 - val_tp: 76074.0000 - val_fp: 779880.0000 - val_tn: 14854817.0000 - val_fn: 1414701.8750 - val_accuracy: 0.8719 - val_precision: 0.0889 - val_recall: 0.0510 - val_auc: 0.5122
# Epoch 12/20
#  - ETA: 4s - loss: 0.2458 - tp: 76074.0000 - fp: 779878.4375 - tn: 15158634.0000 - fn: 1451482.8750 - accuracy: 0.8722 - precision: 0.0889 - recall: 0.0498 - auc: 0.5124
# Epoch 13/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2440 - tp: 76081.3750 - fp: 779896.2500 - tn: 16539595.0000 - fn: 1577872.8750 - accuracy: 0.8757 - precision: 0.0889 - recall: 0.0460 - auc: 0.5141 - val_loss: 0.5131 - val_tp: 76086.0000 - val_fp: 779917.0625 - val_tn: 17102500.0000 - val_fn: 1630818.5000 - val_accuracy: 0.8769 - val_precision: 0.0889 - val_recall: 0.0446 - val_auc: 0.5150
# Epoch 14/20
#  - ETA: 5s - loss: 0.2451 - tp: 76094.0234 - fp: 779925.3750 - tn: 17349890.0000 - fn: 1663606.6250 - accuracy: 0.8770 - precision: 0.0889 - recall: 0.0437 - auc: 0.5152
# Epoch 15/20
#  - ETA: 0s - loss: 0.2437 - tp: 76153.0938 - fp: 780041.2500 - tn: 18719302.0000 - fn: 1789102.5000 - accuracy: 0.8797 - precision: 0.0889 - recall: 0.0408 - auc: 0.5172
# Epoch 16/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2436 - tp: 76217.9219 - fp: 780141.4375 - tn: 19910882.0000 - fn: 1901984.3750 - accuracy: 0.8817 - precision: 0.0890 - recall: 0.0385 - auc: 0.5191 - val_loss: 0.5141 - val_tp: 76241.0000 - val_fp: 780194.9375 - val_tn: 20473804.0000 - val_fn: 1954855.7500 - val_accuracy: 0.8825 - val_precision: 0.0890 - val_recall: 0.0375 - val_auc: 0.5199
# Epoch 17/20
#  - ETA: 3s - loss: 0.2430 - tp: 76248.8438 - fp: 780222.2500 - tn: 20783412.0000 - fn: 1991957.5000 - accuracy: 0.8827 - precision: 0.0890 - recall: 0.0369 - auc: 0.5204
# Epoch 18/20
#  - ETA: 1s - loss: 0.2431 - tp: 76307.8828 - fp: 780331.5000 - tn: 21985576.0000 - fn: 2105558.2500 - accuracy: 0.8843 - precision: 0.0891 - recall: 0.0350 - auc: 0.5224
# Epoch 19/20
#  - ETA: 0s - loss: 0.2436 - tp: 76383.7422 - fp: 780441.5625 - tn: 23234562.0000 - fn: 2222436.7500 - accuracy: 0.8859 - precision: 0.0891 - recall: 0.0332 - auc: 0.5238
# Epoch 20/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2434 - tp: 76451.8672 - fp: 780552.1250 - tn: 24406078.0000 - fn: 2333852.7500 - accuracy: 0.8871 - precision: 0.0892 - recall: 0.0317 - auc: 0.5255 - val_loss: 0.5142 - val_tp: 76486.0000 - val_fp: 780613.3750 - val_tn: 24968844.0000 - val_fn: 2386866.7500 - val_accuracy: 0.8877 - val_precision: 0.0892 - val_recall: 0.0311 - val_auc: 0.5260

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
model.load_weights(initial_weights)
careful_bias_history = model.fit(X_train,
                                 y_train,
                                 batch_size=BATCH_SIZE,
                                 epochs=20,
                                 validation_split=0.2, 
                                 verbose=1)
# Out:
# Built NN...
# Model: "sequential_9"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 16)                208
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2455 - tp: 76486.1719 - fp: 780610.1875 - tn: 25529822.0000 - fn: 2441948.0000 - accuracy: 0.8882 - precision: 0.0892 - recall: 0.0304 - auc: 0.5260 - val_loss: 0.5179 - val_tp: 76486.0000 - val_fp: 780613.3750 - val_tn: 26092724.0000 - val_fn: 2494930.5000 - val_accuracy: 0.8888 - val_precision: 0.0892 - val_recall: 0.0297 - val_auc: 0.5261
# Epoch 2/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2439 - tp: 76486.1719 - fp: 780610.1875 - tn: 26653662.0000 - fn: 2550029.5000 - accuracy: 0.8892 - precision: 0.0892 - recall: 0.0291 - auc: 0.5266 - val_loss: 0.5173 - val_tp: 76486.0000 - val_fp: 780613.3750 - val_tn: 27216560.0000 - val_fn: 2602994.7500 - val_accuracy: 0.8897 - val_precision: 0.0892 - val_recall: 0.0285 - val_auc: 0.5268
# Epoch 3/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2437 - tp: 76514.0000 - fp: 780664.3125 - tn: 27777378.0000 - fn: 2658168.0000 - accuracy: 0.8901 - precision: 0.0893 - recall: 0.0280 - auc: 0.5272 - val_loss: 0.5157 - val_tp: 76556.0000 - val_fp: 780752.7500 - val_tn: 28340294.0000 - val_fn: 2710988.7500 - val_accuracy: 0.8906 - val_precision: 0.0893 - val_recall: 0.0275 - val_auc: 0.5276
# Epoch 4/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2434 - tp: 76609.0938 - fp: 780843.9375 - tn: 28901178.0000 - fn: 2766035.0000 - accuracy: 0.8909 - precision: 0.0893 - recall: 0.0270 - auc: 0.5280 - val_loss: 0.5152 - val_tp: 76666.0000 - val_fp: 780936.7500 - val_tn: 29463992.0000 - val_fn: 2818942.5000 - val_accuracy: 0.8914 - val_precision: 0.0894 - val_recall: 0.0265 - val_auc: 0.5283
# Epoch 5/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2434 - tp: 76714.4766 - fp: 781019.5000 - tn: 30024924.0000 - fn: 2873929.7500 - accuracy: 0.8917 - precision: 0.0894 - recall: 0.0260 - auc: 0.5288 - val_loss: 0.5159 - val_tp: 76758.0000 - val_fp: 781112.0000 - val_tn: 30587654.0000 - val_fn: 2926914.7500 - val_accuracy: 0.8921 - val_precision: 0.0895 - val_recall: 0.0256 - val_auc: 0.5291
# Epoch 6/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2433 - tp: 76798.2656 - fp: 781180.4375 - tn: 31148584.0000 - fn: 2981955.2500 - accuracy: 0.8924 - precision: 0.0895 - recall: 0.0251 - auc: 0.5296 - val_loss: 0.5162 - val_tp: 76844.0000 - val_fp: 781258.6250 - val_tn: 31711420.0000 - val_fn: 3034893.2500 - val_accuracy: 0.8928 - val_precision: 0.0896 - val_recall: 0.0247 - val_auc: 0.5298
# Epoch 7/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2433 - tp: 76883.6719 - fp: 781344.0000 - tn: 32272314.0000 - fn: 3089924.2500 - accuracy: 0.8931 - precision: 0.0896 - recall: 0.0243 - auc: 0.5302 - val_loss: 0.5157 - val_tp: 76917.0000 - val_fp: 781408.1875 - val_tn: 32835110.0000 - val_fn: 3142883.5000 - val_accuracy: 0.8935 - val_precision: 0.0896 - val_recall: 0.0239 - val_auc: 0.5305
# Epoch 8/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2432 - tp: 76949.9453 - fp: 781472.8750 - tn: 33396012.0000 - fn: 3197966.2500 - accuracy: 0.8937 - precision: 0.0896 - recall: 0.0235 - auc: 0.5309 - val_loss: 0.5142 - val_tp: 76977.0000 - val_fp: 781538.9375 - val_tn: 33958892.0000 - val_fn: 3250885.2500 - val_accuracy: 0.8941 - val_precision: 0.0897 - val_recall: 0.0231 - val_auc: 0.5313
# Epoch 9/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2432 - tp: 77010.1094 - fp: 781599.5625 - tn: 34519828.0000 - fn: 3305897.2500 - accuracy: 0.8943 - precision: 0.0897 - recall: 0.0228 - auc: 0.5318 - val_loss: 0.5134 - val_tp: 77041.0000 - val_fp: 781648.7500 - val_tn: 35082636.0000 - val_fn: 3358885.5000 - val_accuracy: 0.8946 - val_precision: 0.0897 - val_recall: 0.0224 - val_auc: 0.5321
# Epoch 10/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2432 - tp: 77065.8438 - fp: 781709.5625 - tn: 35643612.0000 - fn: 3413889.5000 - accuracy: 0.8949 - precision: 0.0897 - recall: 0.0221 - auc: 0.5325 - val_loss: 0.5132 - val_tp: 77104.0000 - val_fp: 781768.7500 - val_tn: 36206368.0000 - val_fn: 3466888.0000 - val_accuracy: 0.8952 - val_precision: 0.0898 - val_recall: 0.0218 - val_auc: 0.5330
# Epoch 11/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2432 - tp: 77135.3203 - fp: 781823.0000 - tn: 36767284.0000 - fn: 3521955.7500 - accuracy: 0.8954 - precision: 0.0898 - recall: 0.0214 - auc: 0.5337 - val_loss: 0.5150 - val_tp: 77159.0000 - val_fp: 781871.8125 - val_tn: 37330148.0000 - val_fn: 3574897.7500 - val_accuracy: 0.8957 - val_precision: 0.0898 - val_recall: 0.0211 - val_auc: 0.5340
# Epoch 12/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2432 - tp: 77188.7266 - fp: 781919.1875 - tn: 37891096.0000 - fn: 3629925.7500 - accuracy: 0.8959 - precision: 0.0898 - recall: 0.0208 - auc: 0.5343 - val_loss: 0.5142 - val_tp: 77211.0000 - val_fp: 781957.3750 - val_tn: 38453928.0000 - val_fn: 3682908.7500 - val_accuracy: 0.8962 - val_precision: 0.0899 - val_recall: 0.0205 - val_auc: 0.5346
# Epoch 13/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2431 - tp: 77224.3125 - fp: 781977.7500 - tn: 39014904.0000 - fn: 3737946.7500 - accuracy: 0.8964 - precision: 0.0899 - recall: 0.0202 - auc: 0.5350 - val_loss: 0.5140 - val_tp: 77247.0000 - val_fp: 782005.3750 - val_tn: 39577760.0000 - val_fn: 3790934.5000 - val_accuracy: 0.8966 - val_precision: 0.0899 - val_recall: 0.0200 - val_auc: 0.5353
# Epoch 14/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2431 - tp: 77260.0234 - fp: 782033.6875 - tn: 40138704.0000 - fn: 3846004.5000 - accuracy: 0.8968 - precision: 0.0899 - recall: 0.0197 - auc: 0.5357 - val_loss: 0.5157 - val_tp: 77275.0000 - val_fp: 782064.7500 - val_tn: 40701608.0000 - val_fn: 3898972.2500 - val_accuracy: 0.8970 - val_precision: 0.0899 - val_recall: 0.0194 - val_auc: 0.5359
# Epoch 15/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2431 - tp: 77289.4062 - fp: 782100.1875 - tn: 41262564.0000 - fn: 3953980.2500 - accuracy: 0.8972 - precision: 0.0899 - recall: 0.0192 - auc: 0.5363 - val_loss: 0.5150 - val_tp: 77307.0000 - val_fp: 782135.8125 - val_tn: 41825336.0000 - val_fn: 4007004.7500 - val_accuracy: 0.8974 - val_precision: 0.0900 - val_recall: 0.0189 - val_auc: 0.5365
# Epoch 16/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2431 - tp: 77320.5938 - fp: 782168.1250 - tn: 42386172.0000 - fn: 4062183.7500 - accuracy: 0.8976 - precision: 0.0900 - recall: 0.0187 - auc: 0.5368 - val_loss: 0.5152 - val_tp: 77338.0000 - val_fp: 782200.1875 - val_tn: 42949120.0000 - val_fn: 4115038.0000 - val_accuracy: 0.8978 - val_precision: 0.0900 - val_recall: 0.0184 - val_auc: 0.5371
# Epoch 17/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2430 - tp: 77369.9453 - fp: 782247.9375 - tn: 43510180.0000 - fn: 4169963.0000 - accuracy: 0.8980 - precision: 0.0900 - recall: 0.0182 - auc: 0.5374 - val_loss: 0.5123 - val_tp: 77401.0000 - val_fp: 782304.7500 - val_tn: 44072880.0000 - val_fn: 4223039.0000 - val_accuracy: 0.8982 - val_precision: 0.0900 - val_recall: 0.0180 - val_auc: 0.5376
# Epoch 18/20
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2431 - tp: 77418.4922 - fp: 782343.6875 - tn: 44633848.0000 - fn: 4278053.5000 - accuracy: 0.8983 - precision: 0.0900 - recall: 0.0178 - auc: 0.5380 - val_loss: 0.5132 - val_tp: 77435.0000 - val_fp: 782392.0000 - val_tn: 45196596.0000 - val_fn: 4331068.5000 - val_accuracy: 0.8985 - val_precision: 0.0901 - val_recall: 0.0176 - val_auc: 0.5382
# Epoch 19/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2431 - tp: 77446.0781 - fp: 782416.8750 - tn: 45757672.0000 - fn: 4386044.5000 - accuracy: 0.8987 - precision: 0.0901 - recall: 0.0174 - auc: 0.5386 - val_loss: 0.5133 - val_tp: 77463.0000 - val_fp: 782455.2500 - val_tn: 46320428.0000 - val_fn: 4439106.5000 - val_accuracy: 0.8988 - val_precision: 0.0901 - val_recall: 0.0172 - val_auc: 0.5388
# Epoch 20/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2430 - tp: 77494.3750 - fp: 782498.6250 - tn: 46881364.0000 - fn: 4494140.0000 - accuracy: 0.8990 - precision: 0.0901 - recall: 0.0170 - auc: 0.5391 - val_loss: 0.5143 - val_tp: 77514.0000 - val_fp: 782544.0000 - val_tn: 47444156.0000 - val_fn: 4547117.5000 - val_accuracy: 0.8992 - val_precision: 0.0901 - val_recall: 0.0168 - val_auc: 0.5393

# %%
def plot_loss(history, label, n):
    # Use a log scale to show the wide range of values.
    plt.semilogy(history.epoch,  
                 history.history['loss'],
                 color=colors[n], 
                 label='Train '+label
                 )
    plt.semilogy(history.epoch,
                 history.history['val_loss'],
                 color=colors[n], 
                 label='Val '+label,
                 linestyle="--")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

# %%
plot_loss(zero_bias_history, "Zero Bias", 0)
plot_loss(careful_bias_history, "Careful Bias", 1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')

baseline_history = model.fit(X_train,
                             y_train,
                             batch_size=BATCH_SIZE,
                             epochs=EPOCHS,
                             callbacks = [early_stopping],
                             validation_split=0.2
                             )
# Out:
# Built NN...
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_16 (Dense)             (None, 16)                208
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.3761 - tp: 82072.1016 - fp: 846489.7500 - tn: 47941208.0000 - fn: 4597628.0000 - accuracy: 0.8982 - precision: 0.0884 - recall: 0.0175 - auc: 0.5380 - val_loss: 0.5197 - val_tp: 82562.0000 - val_fp: 853205.5625 - val_tn: 48497324.0000 - val_fn: 4650132.5000 - val_accuracy: 0.8982 - val_precision: 0.0882 - val_recall: 0.0174 - val_auc: 0.5373
# Epoch 2/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2811 - tp: 82611.3047 - fp: 853637.5625 - tn: 49057892.0000 - fn: 4705148.0000 - accuracy: 0.8984 - precision: 0.0882 - recall: 0.0173 - auc: 0.5368 - val_loss: 0.5132 - val_tp: 82639.0000 - val_fp: 853845.5625 - val_tn: 49620536.0000 - val_fn: 4758119.5000 - val_accuracy: 0.8985 - val_precision: 0.0882 - val_recall: 0.0171 - val_auc: 0.5366
# Epoch 3/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2751 - tp: 82644.5469 - fp: 853885.3750 - tn: 50181524.0000 - fn: 4813166.0000 - accuracy: 0.8987 - precision: 0.0882 - recall: 0.0169 - auc: 0.5364 - val_loss: 0.5100 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 50744360.0000 - val_fn: 4866179.5000 - val_accuracy: 0.8988 - val_precision: 0.0882 - val_recall: 0.0167 - val_auc: 0.5362
# Epoch 4/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2699 - tp: 82646.3047 - fp: 853898.5000 - tn: 51305412.0000 - fn: 4921194.0000 - accuracy: 0.8990 - precision: 0.0882 - recall: 0.0165 - auc: 0.5362 - val_loss: 0.5088 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 51868220.0000 - val_fn: 4974242.0000 - val_accuracy: 0.8991 - val_precision: 0.0882 - val_recall: 0.0163 - val_auc: 0.5361
# Epoch 5/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2648 - tp: 82646.3047 - fp: 853898.5000 - tn: 52429224.0000 - fn: 5029307.0000 - accuracy: 0.8993 - precision: 0.0882 - recall: 0.0162 - auc: 0.5361 - val_loss: 0.5072 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 52992044.0000 - val_fn: 5082309.5000 - val_accuracy: 0.8994 - val_precision: 0.0882 - val_recall: 0.0160 - val_auc: 0.5359
# Epoch 6/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2597 - tp: 82646.3047 - fp: 853898.5000 - tn: 53552888.0000 - fn: 5137546.5000 - accuracy: 0.8995 - precision: 0.0882 - recall: 0.0158 - auc: 0.5360 - val_loss: 0.5081 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 54115920.0000 - val_fn: 5190369.5000 - val_accuracy: 0.8997 - val_precision: 0.0882 - val_recall: 0.0157 - val_auc: 0.5358
# Epoch 7/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2555 - tp: 82646.3047 - fp: 853898.5000 - tn: 54676804.0000 - fn: 5245569.0000 - accuracy: 0.8998 - precision: 0.0882 - recall: 0.0155 - auc: 0.5359 - val_loss: 0.5077 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 55239792.0000 - val_fn: 5298437.0000 - val_accuracy: 0.8999 - val_precision: 0.0882 - val_recall: 0.0154 - val_auc: 0.5358
# Epoch 8/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2523 - tp: 82646.3047 - fp: 853898.5000 - tn: 55800764.0000 - fn: 5353529.0000 - accuracy: 0.9000 - precision: 0.0882 - recall: 0.0152 - auc: 0.5358 - val_loss: 0.5073 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 56363640.0000 - val_fn: 5406497.0000 - val_accuracy: 0.9002 - val_precision: 0.0882 - val_recall: 0.0151 - val_auc: 0.5357
# Epoch 9/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2496 - tp: 82646.3047 - fp: 853898.5000 - tn: 56924716.0000 - fn: 5461533.5000 - accuracy: 0.9003 - precision: 0.0882 - recall: 0.0149 - auc: 0.5358 - val_loss: 0.5064 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 57487504.0000 - val_fn: 5514565.0000 - val_accuracy: 0.9004 - val_precision: 0.0882 - val_recall: 0.0148 - val_auc: 0.5357
# Epoch 10/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2473 - tp: 82646.3047 - fp: 853898.5000 - tn: 58048428.0000 - fn: 5569756.5000 - accuracy: 0.9005 - precision: 0.0882 - recall: 0.0146 - auc: 0.5358 - val_loss: 0.5130 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 58611368.0000 - val_fn: 5622623.5000 - val_accuracy: 0.9006 - val_precision: 0.0882 - val_recall: 0.0145 - val_auc: 0.5357
# Epoch 11/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2461 - tp: 82646.3047 - fp: 853898.5000 - tn: 59172380.0000 - fn: 5677745.5000 - accuracy: 0.9007 - precision: 0.0882 - recall: 0.0143 - auc: 0.5358 - val_loss: 0.5086 - val_tp: 82646.0000 - val_fp: 853904.0000 - val_tn: 59735344.0000 - val_fn: 5730693.0000 - val_accuracy: 0.9008 - val_precision: 0.0882 - val_recall: 0.0142 - val_auc: 0.5358
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %%
def plot_metrics(history):
    metrics =  ['loss', 'auc', 'precision', 'recall']
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.5,1])
        else:
            plt.ylim([0,1])

    plt.legend()

# %%
plot_metrics(baseline_history)
plt.show()

# %%
train_predictions_baseline = model.predict(X_train, batch_size=BATCH_SIZE)
test_predictions_baseline = model.predict(X_test, batch_size=BATCH_SIZE)
print(test_predictions_baseline[:5])
# Out:
# [[0.28854847]
#  [0.07942218]
#  [0.08404306]
#  [0.05376476]
#  [0.04805216]]

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = metrics.confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))

# %%
baseline_results = model.evaluate(X_test, y_test,
                                  batch_size=BATCH_SIZE, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
print()
# Out:
# loss :  0.11702622909853909
# tp :  82646.0
# fp :  853904.0
# tn :  63924644.0
# fn :  5821822.0
# accuracy :  0.9055572152137756
# precision :  0.08824531733989716
# recall :  0.01399718876928091
# auc :  0.530366837978363

# %%
plot_cm(y_test, test_predictions_baseline)
# Out:
# Legitimate Transactions Detected (True Negatives):  302986
# Legitimate Transactions Incorrectly Detected (False Positives):  0
# Fraudulent Transactions Missed (False Negatives):  4966
# Fraudulent Transactions Detected (True Positives):  0
# Total Fraudulent Transactions:  4966

# %%
def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = metrics.roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5,20])
    plt.ylim([80,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %%
plot_roc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.plot([0,100],[0,100],label='baseline',c='red')
plt.legend(loc='lower right')
plt.xlim([0,100])
plt.ylim([0,100])
plt.show()
