# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
import os
import tempfile 


from sklearn import preprocessing
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score, classification_report
from collections import Counter

import tensorflow as tf
import keras


import warnings
warnings.filterwarnings("ignore")
colors = np.array(['#0101DF','#DF0101','#01DF01'])

rs = 42
def compute_metrics (y_te2,y_p,string):
    print('\n %s'%string)
    print('CONFUSION MATRIX')
    print(metrics.confusion_matrix(y_te2,y_p))
    print(classification_report(y_te2, y_p))
    print('\nROC CURVE: %2.2f'%roc_auc_score(y_te2,y_p))

def Ratio10(y,string):
    suma = Counter(y)[0]+Counter(y)[1]
    print('\n'+string)  
    print(Counter(y))
    print('0: %3.2f%%\n1: %3.2f%%' % (100*Counter(y)[0]/suma,100*Counter(y)[1]/suma))

def histo(data,var):
    fig=plt.figure()
    sns.countplot(var,data=data,palette=colors)
    plt.title('0/1 Distribution (0: No Stalling || 1: Stalling Event',fontsize=14)
    plt.show()
# Out:
# Using TensorFlow backend.

# %%
dataset = pd.read_csv('../../output/df_general.csv', sep=',')
split = 0.8
del dataset['No.']
del dataset['Protocol']
del dataset['ip_len']
del dataset['prebuffering']
del dataset['Time']

dataset = dataset.fillna(dataset.mean())
neg, pos = np.bincount(dataset['stalling_event'])

print(dataset.columns)
Ratio10(dataset['stalling_event'],'dataset[stalling_event]')
histo(dataset,'stalling_event')
# Out:
# Index(['∆t', 'pkt_len', 'tcp_hea_len', 'tcp_flag_ack', 'tcp_flag_cwr',
#        'tcp_flag_ecn', 'tcp_flag_urg', 'tcp_flag_psh', 'tcp_flag_rst',
#        'tcp_flag_syn', 'tcp_flag_fin', 'tcp_win_si2', 'delay', 'capture',
#        'stalling_event'],
#       dtype='object')
#
# dataset[stalling_event]
# Counter({0: 1426905, 1: 113031})
# 0: 92.66%
# 1: 7.34%

# %%
from random import randint
'''X_train = [None] * (len(dataset.columns)-1)
X_test = [None] * (len(dataset.columns)-1)'''

X_train = np.array([None]*12)
X_test = np.array([None]*12)
y_train = list()
y_test = list()

grouped = dataset.groupby(['delay','capture']) 
#print(grouped.mean())

for id, data in grouped:
    spl = int(data.shape[0] * split)
    restspl = int(data.shape[0] * (1-split))
    randnum = randint(0,restspl)
    
    X_train = np.vstack((X_train,data.values[randnum:randnum+spl,:-3]))
    X_test = np.vstack((X_test,data.values[0:randnum-1,:-3]))
    X_test = np.vstack((X_test,data.values[randnum+spl:,:-3]))
    
    y_train.extend(data.values[randnum:randnum+spl,-1])
    y_test.extend(data.values[0:randnum-1,-1])
    y_test.extend(data.values[randnum+spl:,-1])

X_train = X_train[1:]
X_test = X_test[1:]

X_train = pd.DataFrame(data=X_train,columns=dataset.columns[:-3])
X_test= pd.DataFrame(data=X_test,columns=dataset.columns[:-3])
del dataset['delay']
del dataset['capture']

# %%
mms = preprocessing.MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)

# %%
y_test = list(map(int,y_test))
y_train = list(map(int,y_train))
Ratio10(y_test,'y_test')
Ratio10(y_train,'y_train')
# Out:
# y_test
# Counter({0: 302790, 1: 5162})
# 0: 98.32%
# 1: 1.68%
#
# y_train
# Counter({0: 1124058, 1: 107866})
# 0: 91.24%
# 1: 8.76%

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.TrueNegatives(name='tn'),
    tf.keras.metrics.FalseNegatives(name='fn'),
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
]

EPOCHS = 100
BATCH_SIZE = 2048

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', 
                                                  verbose=1,
                                                  patience=10,
                                                  mode='max',
                                                  restore_best_weights=True)

# %%
n_features = X_train.shape[1]
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(16,activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# 1231924/1231924 [==============================] - 6s 5us/step
# Loss: 0.7769

# %%
initial_bias = np.log([pos/neg])
print(initial_bias)
# Out:
# [-2.53560092]

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(16,activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid',bias_initializer=keras.initializers.Constant(initial_bias)))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# 1231924/1231924 [==============================] - 5s 4us/step
# Loss: 0.2987

# %%
initial_weights = os.path.join(tempfile.mkdtemp(),'initial_weights')
model.save_weights(initial_weights)

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(16,activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')

model.load_weights(initial_weights)
model.layers[-1].bias.assign([0.0])
zero_bias_history = model.fit(X_train,
                              y_train,
                              batch_size=BATCH_SIZE,
                              epochs=20,
                              validation_split=0.2, 
                              verbose=1)
# Out:
# Built NN...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 16)                272
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.3440 - tp: 109452.7969 - fp: 1149172.1250 - tn: 1560020.1250 - fn: 139792.1250 - accuracy: 0.5609 - precision: 0.0870 - recall: 0.4417 - auc: 0.5033 - val_loss: 0.5075 - val_tp: 109558.0000 - val_fp: 1150528.1250 - val_tn: 2122090.7500 - val_fn: 192125.6875 - val_accuracy: 0.6243 - val_precision: 0.0869 - val_recall: 0.3638 - val_auc: 0.4991
# Epoch 2/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2771 - tp: 109559.8828 - fp: 1150528.3750 - tn: 2682751.2500 - fn: 247514.4531 - accuracy: 0.6651 - precision: 0.0869 - recall: 0.3077 - auc: 0.4940 - val_loss: 0.4986 - val_tp: 109562.0000 - val_fp: 1150536.8750 - val_tn: 3246138.0000 - val_fn: 299987.6875 - val_accuracy: 0.6982 - val_precision: 0.0869 - val_recall: 0.2678 - val_auc: 0.4959
# Epoch 3/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2688 - tp: 109561.2812 - fp: 1150534.2500 - tn: 3806892.5000 - fn: 355288.9375 - accuracy: 0.7217 - precision: 0.0869 - recall: 0.2361 - auc: 0.4966 - val_loss: 0.5012 - val_tp: 109562.0000 - val_fp: 1150543.5000 - val_tn: 4370195.0000 - val_fn: 407853.9062 - val_accuracy: 0.7419 - val_precision: 0.0869 - val_recall: 0.2119 - val_auc: 0.4976
# Epoch 4/20
#  - ETA: 0s - loss: 0.2638 - tp: 109561.3594 - fp: 1150536.1250 - tn: 4904201.5000 - fn: 461233.0938 - accuracy: 0.7564 - precision: 0.0869 - recall: 0.1921 - auc: 0.4978
# Epoch 5/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2600 - tp: 109563.5000 - fp: 1150535.7500 - tn: 6054964.5000 - fn: 571061.5000 - accuracy: 0.7815 - precision: 0.0869 - recall: 0.1611 - auc: 0.5008 - val_loss: 0.4972 - val_tp: 109563.0000 - val_fp: 1150543.8750 - val_tn: 6618311.5000 - val_fn: 623584.4375 - val_accuracy: 0.7913 - val_precision: 0.0869 - val_recall: 0.1495 - val_auc: 0.5020
# Epoch 6/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2574 - tp: 109563.6797 - fp: 1150535.7500 - tn: 7178876.5000 - fn: 679075.0000 - accuracy: 0.7992 - precision: 0.0869 - recall: 0.1390 - auc: 0.5030 - val_loss: 0.4994 - val_tp: 109563.0000 - val_fp: 1150543.8750 - val_tn: 7742367.0000 - val_fn: 731450.7500 - val_accuracy: 0.8067 - val_precision: 0.0869 - val_recall: 0.1303 - val_auc: 0.5036
# Epoch 7/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2545 - tp: 109563.6797 - fp: 1150535.7500 - tn: 8303089.0000 - fn: 786783.5625 - accuracy: 0.8127 - precision: 0.0869 - recall: 0.1223 - auc: 0.5044 - val_loss: 0.4967 - val_tp: 109563.0000 - val_fp: 1150543.8750 - val_tn: 8866421.0000 - val_fn: 839316.5000 - val_accuracy: 0.8185 - val_precision: 0.0869 - val_recall: 0.1155 - val_auc: 0.5053
# Epoch 8/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2523 - tp: 109563.6797 - fp: 1150535.7500 - tn: 9427155.0000 - fn: 894642.8125 - accuracy: 0.8233 - precision: 0.0869 - recall: 0.1091 - auc: 0.5062 - val_loss: 0.4993 - val_tp: 109563.0000 - val_fp: 1150543.8750 - val_tn: 9990488.0000 - val_fn: 947182.8125 - val_accuracy: 0.8280 - val_precision: 0.0869 - val_recall: 0.1037 - val_auc: 0.5068
# Epoch 9/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2505 - tp: 109563.6797 - fp: 1150535.7500 - tn: 10551160.0000 - fn: 1002564.9375 - accuracy: 0.8319 - precision: 0.0869 - recall: 0.0985 - auc: 0.5075 - val_loss: 0.4990 - val_tp: 109563.0000 - val_fp: 1150543.8750 - val_tn: 11114532.0000 - val_fn: 1055048.2500 - val_accuracy: 0.8358 - val_precision: 0.0869 - val_recall: 0.0941 - val_auc: 0.5082
# Epoch 10/20
#  - ETA: 3s - loss: 0.2516 - tp: 109562.9922 - fp: 1150543.8750 - tn: 11362911.0000 - fn: 1087890.6250 - accuracy: 0.8367 - precision: 0.0869 - recall: 0.0915 - auc: 0.5083
# Epoch 11/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2479 - tp: 109563.6797 - fp: 1150535.7500 - tn: 12799450.0000 - fn: 1218123.2500 - accuracy: 0.8449 - precision: 0.0869 - recall: 0.0825 - auc: 0.5105 - val_loss: 0.4992 - val_tp: 109563.0000 - val_fp: 1150544.0000 - val_tn: 13362674.0000 - val_fn: 1270779.7500 - val_accuracy: 0.8477 - val_precision: 0.0869 - val_recall: 0.0794 - val_auc: 0.5113
# Epoch 12/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2471 - tp: 109563.6797 - fp: 1150551.2500 - tn: 13923441.0000 - fn: 1326049.8750 - accuracy: 0.8500 - precision: 0.0869 - recall: 0.0763 - auc: 0.5123 - val_loss: 0.5008 - val_tp: 109565.0000 - val_fp: 1150550.0000 - val_tn: 14486694.0000 - val_fn: 1378645.1250 - val_accuracy: 0.8523 - val_precision: 0.0869 - val_recall: 0.0736 - val_auc: 0.5130
# Epoch 13/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2466 - tp: 109568.1797 - fp: 1150558.3750 - tn: 15047429.0000 - fn: 1433975.3750 - accuracy: 0.8543 - precision: 0.0870 - recall: 0.0710 - auc: 0.5141 - val_loss: 0.5006 - val_tp: 109573.0000 - val_fp: 1150575.5000 - val_tn: 15610739.0000 - val_fn: 1486502.8750 - val_accuracy: 0.8563 - val_precision: 0.0870 - val_recall: 0.0687 - val_auc: 0.5149
# Epoch 14/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2462 - tp: 109584.7188 - fp: 1150584.8750 - tn: 16171427.0000 - fn: 1541848.3750 - accuracy: 0.8581 - precision: 0.0870 - recall: 0.0664 - auc: 0.5159 - val_loss: 0.5037 - val_tp: 109595.0000 - val_fp: 1150608.0000 - val_tn: 16734755.0000 - val_fn: 1594346.0000 - val_accuracy: 0.8599 - val_precision: 0.0870 - val_recall: 0.0643 - val_auc: 0.5165
# Epoch 15/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2461 - tp: 109605.7891 - fp: 1150633.7500 - tn: 17295578.0000 - fn: 1649562.8750 - accuracy: 0.8614 - precision: 0.0870 - recall: 0.0623 - auc: 0.5172 - val_loss: 0.5020 - val_tp: 109614.0000 - val_fp: 1150655.8750 - val_tn: 17858804.0000 - val_fn: 1702194.3750 - val_accuracy: 0.8630 - val_precision: 0.0870 - val_recall: 0.0605 - val_auc: 0.5180
# Epoch 16/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2459 - tp: 109623.8516 - fp: 1150678.5000 - tn: 18419448.0000 - fn: 1757560.2500 - accuracy: 0.8643 - precision: 0.0870 - recall: 0.0587 - auc: 0.5191 - val_loss: 0.5050 - val_tp: 109634.0000 - val_fp: 1150704.0000 - val_tn: 18982804.0000 - val_fn: 1810040.1250 - val_accuracy: 0.8657 - val_precision: 0.0870 - val_recall: 0.0571 - val_auc: 0.5197
# Epoch 17/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2457 - tp: 109645.8125 - fp: 1150724.0000 - tn: 19543452.0000 - fn: 1865408.8750 - accuracy: 0.8669 - precision: 0.0870 - recall: 0.0555 - auc: 0.5204 - val_loss: 0.5047 - val_tp: 109657.0000 - val_fp: 1150738.0000 - val_tn: 20106802.0000 - val_fn: 1917881.8750 - val_accuracy: 0.8682 - val_precision: 0.0870 - val_recall: 0.0541 - val_auc: 0.5211
# Epoch 18/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2457 - tp: 109668.2578 - fp: 1150768.2500 - tn: 20667486.0000 - fn: 1973209.7500 - accuracy: 0.8693 - precision: 0.0870 - recall: 0.0527 - auc: 0.5219 - val_loss: 0.5056 - val_tp: 109677.0000 - val_fp: 1150791.1250 - val_tn: 21230786.0000 - val_fn: 2025728.5000 - val_accuracy: 0.8704 - val_precision: 0.0870 - val_recall: 0.0514 - val_auc: 0.5224
# Epoch 19/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2456 - tp: 109686.0078 - fp: 1150821.1250 - tn: 21791462.0000 - fn: 2081092.5000 - accuracy: 0.8714 - precision: 0.0870 - recall: 0.0501 - auc: 0.5231 - val_loss: 0.5059 - val_tp: 109695.0000 - val_fp: 1150847.5000 - val_tn: 22354802.0000 - val_fn: 2133576.5000 - val_accuracy: 0.8724 - val_precision: 0.0870 - val_recall: 0.0489 - val_auc: 0.5237
# Epoch 20/20
#  - ETA: 3s - loss: 0.2450 - tp: 109701.9141 - fp: 1150854.7500 - tn: 22649210.0000 - fn: 2169505.7500 - accuracy: 0.8727 - precision: 0.0870 - recall: 0.0481 - auc: 0.5238

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(16,activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
model.load_weights(initial_weights)
careful_bias_history = model.fit(X_train,
                                 y_train,
                                 batch_size=BATCH_SIZE,
                                 epochs=20,
                                 validation_split=0.2, 
                                 verbose=1)
# Out:
# Built NN...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_10 (Dense)             (None, 16)                208
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_11 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2474 - tp: 109716.3125 - fp: 1150904.7500 - tn: 24039518.0000 - fn: 2296764.0000 - accuracy: 0.8751 - precision: 0.0870 - recall: 0.0456 - auc: 0.5243 - val_loss: 0.5071 - val_tp: 109717.0000 - val_fp: 1150897.8750 - val_tn: 24602830.0000 - val_fn: 2349287.7500 - val_accuracy: 0.8759 - val_precision: 0.0870 - val_recall: 0.0446 - val_auc: 0.5243
# Epoch 2/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2464 - tp: 109718.9844 - fp: 1150905.6250 - tn: 25163598.0000 - fn: 2404581.7500 - accuracy: 0.8767 - precision: 0.0870 - recall: 0.0436 - auc: 0.5246 - val_loss: 0.5064 - val_tp: 109726.0000 - val_fp: 1150934.0000 - val_tn: 25726864.0000 - val_fn: 2457144.5000 - val_accuracy: 0.8775 - val_precision: 0.0870 - val_recall: 0.0427 - val_auc: 0.5249
# Epoch 3/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2461 - tp: 109744.3672 - fp: 1150965.7500 - tn: 26287506.0000 - fn: 2512515.5000 - accuracy: 0.8781 - precision: 0.0870 - recall: 0.0419 - auc: 0.5255 - val_loss: 0.5060 - val_tp: 109766.0000 - val_fp: 1151007.5000 - val_tn: 26850874.0000 - val_fn: 2564969.5000 - val_accuracy: 0.8789 - val_precision: 0.0871 - val_recall: 0.0410 - val_auc: 0.5257
# Epoch 4/20
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2459 - tp: 109784.3984 - fp: 1151067.0000 - tn: 27411502.0000 - fn: 2620306.5000 - accuracy: 0.8795 - precision: 0.0871 - recall: 0.0402 - auc: 0.5261 - val_loss: 0.5030 - val_tp: 109798.0000 - val_fp: 1151128.3750 - val_tn: 27974834.0000 - val_fn: 2672804.7500 - val_accuracy: 0.8802 - val_precision: 0.0871 - val_recall: 0.0395 - val_auc: 0.5266
# Epoch 5/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2458 - tp: 109814.5234 - fp: 1151172.2500 - tn: 28535354.0000 - fn: 2728254.7500 - accuracy: 0.8807 - precision: 0.0871 - recall: 0.0387 - auc: 0.5272 - val_loss: 0.5041 - val_tp: 109832.0000 - val_fp: 1151218.0000 - val_tn: 29098776.0000 - val_fn: 2780635.7500 - val_accuracy: 0.8814 - val_precision: 0.0871 - val_recall: 0.0380 - val_auc: 0.5275
# Epoch 6/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2457 - tp: 109857.3906 - fp: 1151280.2500 - tn: 29659496.0000 - fn: 2835893.0000 - accuracy: 0.8819 - precision: 0.0871 - recall: 0.0373 - auc: 0.5279 - val_loss: 0.5027 - val_tp: 109885.0000 - val_fp: 1151335.5000 - val_tn: 30222718.0000 - val_fn: 2888449.2500 - val_accuracy: 0.8825 - val_precision: 0.0871 - val_recall: 0.0366 - val_auc: 0.5283
# Epoch 7/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2456 - tp: 109907.3047 - fp: 1151380.5000 - tn: 30783322.0000 - fn: 2943827.0000 - accuracy: 0.8830 - precision: 0.0871 - recall: 0.0360 - auc: 0.5288 - val_loss: 0.5028 - val_tp: 109926.0000 - val_fp: 1151431.1250 - val_tn: 31346682.0000 - val_fn: 2996273.7500 - val_accuracy: 0.8835 - val_precision: 0.0871 - val_recall: 0.0354 - val_auc: 0.5292
# Epoch 8/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2456 - tp: 109949.0391 - fp: 1151481.0000 - tn: 31907408.0000 - fn: 3051515.5000 - accuracy: 0.8840 - precision: 0.0872 - recall: 0.0348 - auc: 0.5297 - val_loss: 0.5035 - val_tp: 109979.0000 - val_fp: 1151534.1250 - val_tn: 32470594.0000 - val_fn: 3104087.5000 - val_accuracy: 0.8845 - val_precision: 0.0872 - val_recall: 0.0342 - val_auc: 0.5299
# Epoch 9/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2456 - tp: 110002.2109 - fp: 1151599.2500 - tn: 33031248.0000 - fn: 3159410.2500 - accuracy: 0.8849 - precision: 0.0872 - recall: 0.0336 - auc: 0.5303 - val_loss: 0.5040 - val_tp: 110024.0000 - val_fp: 1151655.6250 - val_tn: 33594528.0000 - val_fn: 3211907.5000 - val_accuracy: 0.8854 - val_precision: 0.0872 - val_recall: 0.0331 - val_auc: 0.5307
# Epoch 10/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2455 - tp: 110055.6484 - fp: 1151717.6250 - tn: 34155204.0000 - fn: 3267209.2500 - accuracy: 0.8858 - precision: 0.0872 - recall: 0.0326 - auc: 0.5311 - val_loss: 0.5030 - val_tp: 110088.0000 - val_fp: 1151770.0000 - val_tn: 34718472.0000 - val_fn: 3319710.2500 - val_accuracy: 0.8862 - val_precision: 0.0872 - val_recall: 0.0321 - val_auc: 0.5314
# Epoch 11/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2455 - tp: 110116.7969 - fp: 1151829.0000 - tn: 35279072.0000 - fn: 3375078.7500 - accuracy: 0.8866 - precision: 0.0873 - recall: 0.0316 - auc: 0.5318 - val_loss: 0.5049 - val_tp: 110142.0000 - val_fp: 1151880.8750 - val_tn: 35842404.0000 - val_fn: 3427522.7500 - val_accuracy: 0.8870 - val_precision: 0.0873 - val_recall: 0.0311 - val_auc: 0.5320
# Epoch 12/20
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2455 - tp: 110169.3125 - fp: 1151942.6250 - tn: 36403012.0000 - fn: 3482892.7500 - accuracy: 0.8874 - precision: 0.0873 - recall: 0.0307 - auc: 0.5324 - val_loss: 0.5021 - val_tp: 110196.0000 - val_fp: 1151999.8750 - val_tn: 36966352.0000 - val_fn: 3535332.2500 - val_accuracy: 0.8878 - val_precision: 0.0873 - val_recall: 0.0302 - val_auc: 0.5327
# Epoch 13/20
# 985539/985539 [==============================] - 6s 7us/step - loss: 0.2455 - tp: 110226.8125 - fp: 1152057.5000 - tn: 37527092.0000 - fn: 3590550.5000 - accuracy: 0.8881 - precision: 0.0873 - recall: 0.0298 - auc: 0.5331 - val_loss: 0.5035 - val_tp: 110253.0000 - val_fp: 1152126.1250 - val_tn: 38090284.0000 - val_fn: 3643140.5000 - val_accuracy: 0.8885 - val_precision: 0.0873 - val_recall: 0.0294 - val_auc: 0.5334
# Epoch 14/20
#  - ETA: 0s - loss: 0.2454 - tp: 110278.8828 - fp: 1152171.7500 - tn: 38580308.0000 - fn: 3693332.0000 - accuracy: 0.8887 - precision: 0.0874 - recall: 0.0290 - auc: 0.5337
# Epoch 15/20
#  - ETA: 2s - loss: 0.2458 - tp: 110322.6719 - fp: 1152265.1250 - tn: 39584824.0000 - fn: 3792560.5000 - accuracy: 0.8892 - precision: 0.0874 - recall: 0.0283 - auc: 0.5342
# Epoch 16/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2454 - tp: 110391.3516 - fp: 1152383.3750 - tn: 40898884.0000 - fn: 3913964.2500 - accuracy: 0.8900 - precision: 0.0874 - recall: 0.0274 - auc: 0.5350 - val_loss: 0.5043 - val_tp: 110415.0000 - val_fp: 1152433.8750 - val_tn: 41462048.0000 - val_fn: 3966578.7500 - val_accuracy: 0.8904 - val_precision: 0.0874 - val_recall: 0.0271 - val_auc: 0.5352
# Epoch 17/20
#  - ETA: 0s - loss: 0.2456 - tp: 110443.5547 - fp: 1152492.0000 - tn: 41972984.0000 - fn: 4018353.5000 - accuracy: 0.8906 - precision: 0.0874 - recall: 0.0267 - auc: 0.5355
# Epoch 18/20
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2454 - tp: 110510.1875 - fp: 1152624.1250 - tn: 43146496.0000 - fn: 4129785.0000 - accuracy: 0.8912 - precision: 0.0875 - recall: 0.0261 - auc: 0.5359 - val_loss: 0.5029 - val_tp: 110537.0000 - val_fp: 1152682.0000 - val_tn: 43709888.0000 - val_fn: 4182188.7500 - val_accuracy: 0.8915 - val_precision: 0.0875 - val_recall: 0.0258 - val_auc: 0.5362
# Epoch 19/20
# 985539/985539 [==============================] - 6s 7us/step - loss: 0.2454 - tp: 110555.2578 - fp: 1152730.7500 - tn: 44270568.0000 - fn: 4237456.5000 - accuracy: 0.8917 - precision: 0.0875 - recall: 0.0254 - auc: 0.5365 - val_loss: 0.5030 - val_tp: 110581.0000 - val_fp: 1152794.0000 - val_tn: 44833764.0000 - val_fn: 4290012.0000 - val_accuracy: 0.8920 - val_precision: 0.0875 - val_recall: 0.0251 - val_auc: 0.5366
# Epoch 20/20
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2454 - tp: 110603.6719 - fp: 1152844.6250 - tn: 45394404.0000 - fn: 4345326.5000 - accuracy: 0.8922 - precision: 0.0875 - recall: 0.0248 - auc: 0.5369 - val_loss: 0.5037 - val_tp: 110626.0000 - val_fp: 1152888.8750 - val_tn: 45957696.0000 - val_fn: 4397830.5000 - val_accuracy: 0.8925 - val_precision: 0.0876 - val_recall: 0.0245 - val_auc: 0.5371

# %%
def plot_loss(history, label, n):
    # Use a log scale to show the wide range of values.
    plt.semilogy(history.epoch,  
                 history.history['loss'],
                 color=colors[n], 
                 label='Train '+label
                 )
    plt.semilogy(history.epoch,
                 history.history['val_loss'],
                 color=colors[n], 
                 label='Val '+label,
                 linestyle="--")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

# %%
plot_loss(zero_bias_history, "Zero Bias", 0)
plot_loss(careful_bias_history, "Careful Bias", 1)
plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(16,activation='relu'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')

baseline_history = model.fit(X_train,
                             y_train,
                             batch_size=BATCH_SIZE,
                             epochs=EPOCHS,
                             callbacks = [early_stopping],
                             validation_split=0.2
                             )
# Out:
# Built NN...
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_13 (Dense)             (None, 16)                208
# _________________________________________________________________
# dropout_9 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_14 (Dense)             (None, 16)                272
# _________________________________________________________________
# dropout_10 (Dropout)         (None, 16)                0
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 17
# =================================================================
# Total params: 497
# Trainable params: 497
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.3089 - tp: 111080.4609 - fp: 1158621.2500 - tn: 46512580.0000 - fn: 4452803.0000 - accuracy: 0.8926 - precision: 0.0875 - recall: 0.0243 - auc: 0.5363 - val_loss: 0.4994 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 47075608.0000 - val_fn: 4505212.0000 - val_accuracy: 0.8928 - val_precision: 0.0875 - val_recall: 0.0241 - val_auc: 0.5360
# Epoch 2/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2727 - tp: 111111.6875 - fp: 1159009.7500 - tn: 47636284.0000 - fn: 4560572.0000 - accuracy: 0.8930 - precision: 0.0875 - recall: 0.0238 - auc: 0.5359 - val_loss: 0.4996 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 48199652.0000 - val_fn: 4613079.5000 - val_accuracy: 0.8933 - val_precision: 0.0875 - val_recall: 0.0235 - val_auc: 0.5356
# Epoch 3/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2616 - tp: 111111.6875 - fp: 1159009.7500 - tn: 48760312.0000 - fn: 4668468.5000 - accuracy: 0.8935 - precision: 0.0875 - recall: 0.0232 - auc: 0.5357 - val_loss: 0.5028 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 49323728.0000 - val_fn: 4720946.0000 - val_accuracy: 0.8937 - val_precision: 0.0875 - val_recall: 0.0230 - val_auc: 0.5355
# Epoch 4/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2581 - tp: 111111.6875 - fp: 1159009.7500 - tn: 49884388.0000 - fn: 4776326.0000 - accuracy: 0.8939 - precision: 0.0875 - recall: 0.0227 - auc: 0.5354 - val_loss: 0.5011 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 50447784.0000 - val_fn: 4828812.0000 - val_accuracy: 0.8941 - val_precision: 0.0875 - val_recall: 0.0225 - val_auc: 0.5353
# Epoch 5/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2559 - tp: 111111.6875 - fp: 1159009.7500 - tn: 51008432.0000 - fn: 4884209.0000 - accuracy: 0.8943 - precision: 0.0875 - recall: 0.0222 - auc: 0.5353 - val_loss: 0.5025 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 51571828.0000 - val_fn: 4936675.5000 - val_accuracy: 0.8945 - val_precision: 0.0875 - val_recall: 0.0220 - val_auc: 0.5351
# Epoch 6/100
# 985539/985539 [==============================] - 6s 7us/step - loss: 0.2539 - tp: 111111.6875 - fp: 1159009.7500 - tn: 52132580.0000 - fn: 4992003.0000 - accuracy: 0.8947 - precision: 0.0875 - recall: 0.0218 - auc: 0.5350 - val_loss: 0.5003 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 52695884.0000 - val_fn: 5044538.0000 - val_accuracy: 0.8949 - val_precision: 0.0875 - val_recall: 0.0216 - val_auc: 0.5349
# Epoch 7/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2518 - tp: 111111.6875 - fp: 1159009.7500 - tn: 53256708.0000 - fn: 5099802.0000 - accuracy: 0.8950 - precision: 0.0875 - recall: 0.0213 - auc: 0.5349 - val_loss: 0.4995 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 53819972.0000 - val_fn: 5152411.5000 - val_accuracy: 0.8952 - val_precision: 0.0875 - val_recall: 0.0211 - val_auc: 0.5348
# Epoch 8/100
#  - ETA: 2s - loss: 0.2509 - tp: 111111.4531 - fp: 1159008.7500 - tn: 54184900.0000 - fn: 5193579.0000 - accuracy: 0.8953 - precision: 0.0875 - recall: 0.0209 - auc: 0.5349
# Epoch 9/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2488 - tp: 111111.6875 - fp: 1159009.7500 - tn: 55504620.0000 - fn: 5315667.0000 - accuracy: 0.8957 - precision: 0.0875 - recall: 0.0205 - auc: 0.5348 - val_loss: 0.5005 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 56068004.0000 - val_fn: 5368145.0000 - val_accuracy: 0.8959 - val_precision: 0.0875 - val_recall: 0.0203 - val_auc: 0.5347
# Epoch 10/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2479 - tp: 111111.6875 - fp: 1159009.7500 - tn: 56628852.0000 - fn: 5423373.5000 - accuracy: 0.8960 - precision: 0.0875 - recall: 0.0201 - auc: 0.5348 - val_loss: 0.4986 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 57192112.0000 - val_fn: 5476006.0000 - val_accuracy: 0.8962 - val_precision: 0.0875 - val_recall: 0.0199 - val_auc: 0.5348
# Epoch 11/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2472 - tp: 111111.6875 - fp: 1159009.7500 - tn: 57752820.0000 - fn: 5531364.0000 - accuracy: 0.8964 - precision: 0.0875 - recall: 0.0197 - auc: 0.5349 - val_loss: 0.4989 - val_tp: 111111.0000 - val_fp: 1159009.8750 - val_tn: 58316172.0000 - val_fn: 5583870.0000 - val_accuracy: 0.8965 - val_precision: 0.0875 - val_recall: 0.0195 - val_auc: 0.5349
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %%
def plot_metrics(history):
    metrics =  ['loss', 'auc', 'precision', 'recall']
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.5,1])
        else:
            plt.ylim([0,1])

    plt.legend()

# %%
plot_metrics(baseline_history)
plt.show()

# %%
train_predictions_baseline = model.predict(X_train, batch_size=BATCH_SIZE)
test_predictions_baseline = model.predict(X_test, batch_size=BATCH_SIZE)
print(test_predictions_baseline[:5])
# Out:
# [[0.1679171 ]
#  [0.13293439]
#  [0.06048608]
#  [0.06642404]
#  [0.08441314]]

# %%
def plot_cm(labels, predictions, p=0.5):
  cm = metrics.confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))

# %%
baseline_results = model.evaluate(X_test, y_test,
                                  batch_size=BATCH_SIZE, verbose=0)
for name, value in zip(model.metrics_names, baseline_results):
    print(name, ': ', value)
print()
# Out:
# loss :  0.11540508755226907
# tp :  111110.9921875
# fp :  1159009.5
# tn :  58566980.0
# fn :  5610113.0
# accuracy :  0.8965670466423035
# precision :  0.08748055249452591
# recall :  0.019420839846134186
# auc :  0.5351040959358215

# %%
plot_cm(y_test, test_predictions_baseline)
# Out:
# Legitimate Transactions Detected (True Negatives):  302790
# Legitimate Transactions Incorrectly Detected (False Positives):  0
# Fraudulent Transactions Missed (False Negatives):  5162
# Fraudulent Transactions Detected (True Positives):  0
# Total Fraudulent Transactions:  5162

# %%
def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = metrics.roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5,20])
    plt.ylim([80,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %%
plot_roc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')
plt.plot([0,100],[0,100],label='baseline',c='red')
plt.legend(loc='lower right')
plt.xlim([0,100])
plt.ylim([0,100])
plt.show()
