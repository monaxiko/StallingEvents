# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn.metrics as metrics
import os
import tempfile 


from sklearn import preprocessing
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score, classification_report
from collections import Counter

import tensorflow as tf
import keras


import warnings
warnings.filterwarnings("ignore")
colors = np.array(['#0101DF','#DF0101','#01DF01'])

rs = 42
def compute_metrics (y_te2,y_p,string):
    print('\n %s'%string)
    print('CONFUSION MATRIX')
    print(metrics.confusion_matrix(y_te2,y_p))
    print(classification_report(y_te2, y_p))
    print('\nROC CURVE: %2.2f'%roc_auc_score(y_te2,y_p))

def Ratio10(y,string):
    suma = Counter(y)[0]+Counter(y)[1]
    print('\n'+string)  
    print(Counter(y))
    print('0: %3.2f%%\n1: %3.2f%%' % (100*Counter(y)[0]/suma,100*Counter(y)[1]/suma))

def histo(data,var):
    fig=plt.figure()
    sns.countplot(var,data=data,palette=colors)
    plt.title('0/1 Distribution (0: No Stalling || 1: Stalling Event',fontsize=14)
    plt.show()
    
def plot_loss(history, label, n):
    # Use a log scale to show the wide range of values.
    plt.semilogy(history.epoch,  
                 history.history['loss'],
                 color=colors[n], 
                 label='Train '+label
                 )
    plt.semilogy(history.epoch,
                 history.history['val_loss'],
                 color=colors[n], 
                 label='Val '+label,
                 linestyle="--")
    plt.xlabel('Epoch')
    plt.ylabel('Loss')
    plt.legend()

def plot_metrics(history):
    metrics =  ['loss', 'auc', 'precision', 'recall']
    for n, metric in enumerate(metrics):
        name = metric.replace("_"," ").capitalize()
        plt.subplot(2,2,n+1)
        plt.plot(history.epoch,  history.history[metric], color=colors[0], label='Train')
        plt.plot(history.epoch, history.history['val_'+metric],
             color=colors[0], linestyle="--", label='Val')
        plt.xlabel('Epoch')
        plt.ylabel(name)
        if metric == 'loss':
            plt.ylim([0, plt.ylim()[1]])
        elif metric == 'auc':
            plt.ylim([0.5,1])
        else:
            plt.ylim([0,1])

    plt.legend()

def plot_cm(labels, predictions, p=0.5):
  cm = metrics.confusion_matrix(labels, predictions > p)
  plt.figure(figsize=(5,5))
  sns.heatmap(cm, annot=True, fmt="d")
  plt.title('Confusion matrix @{:.2f}'.format(p))
  plt.ylabel('Actual label')
  plt.xlabel('Predicted label')

  print('Legitimate Transactions Detected (True Negatives): ', cm[0][0])
  print('Legitimate Transactions Incorrectly Detected (False Positives): ', cm[0][1])
  print('Fraudulent Transactions Missed (False Negatives): ', cm[1][0])
  print('Fraudulent Transactions Detected (True Positives): ', cm[1][1])
  print('Total Fraudulent Transactions: ', np.sum(cm[1]))
  

def plot_roc(name, labels, predictions, **kwargs):
    fp, tp, _ = metrics.roc_curve(labels, predictions)

    plt.plot(100*fp, 100*tp, label=name, linewidth=2, **kwargs)
    plt.xlabel('False positives [%]')
    plt.ylabel('True positives [%]')
    plt.xlim([-0.5,100.5])
    plt.ylim([-0.5,100.5])
    plt.grid(True)
    ax = plt.gca()
    ax.set_aspect('equal')

# %%
dataset = pd.read_csv('../../output/df_general.csv', sep=',')
split = 0.8
del dataset['No.']
del dataset['Protocol']
del dataset['ip_len']
del dataset['prebuffering']
del dataset['Time']

dataset = dataset.fillna(dataset.mean())
neg, pos = np.bincount(dataset['stalling_event'])
total = neg + pos
weight_for_0 = (1 / neg)*(total)/2.0 
weight_for_1 = (1 / pos)*(total)/2.0

class_weight = {0: weight_for_0, 1: weight_for_1}

print(dataset.columns)
Ratio10(dataset['stalling_event'],'dataset[stalling_event]')
histo(dataset,'stalling_event')
# Out:
# Index(['∆t', 'pkt_len', 'tcp_hea_len', 'tcp_flag_ack', 'tcp_flag_cwr',
#        'tcp_flag_ecn', 'tcp_flag_urg', 'tcp_flag_psh', 'tcp_flag_rst',
#        'tcp_flag_syn', 'tcp_flag_fin', 'tcp_win_si2', 'delay', 'capture',
#        'stalling_event'],
#       dtype='object')
#
# dataset[stalling_event]
# Counter({0: 1426905, 1: 113031})
# 0: 92.66%
# 1: 7.34%

# %%
from random import randint
'''X_train = [None] * (len(dataset.columns)-1)
X_test = [None] * (len(dataset.columns)-1)'''

X_train = np.array([None]*12)
X_test = np.array([None]*12)
y_train = list()
y_test = list()

grouped = dataset.groupby(['delay','capture']) 
#print(grouped.mean())

for id, data in grouped:
    spl = int(data.shape[0] * split)
    restspl = int(data.shape[0] * (1-split))
    randnum = randint(0,restspl)
    
    X_train = np.vstack((X_train,data.values[randnum:randnum+spl,:-3]))
    X_test = np.vstack((X_test,data.values[0:randnum-1,:-3]))
    X_test = np.vstack((X_test,data.values[randnum+spl:,:-3]))
    
    y_train.extend(data.values[randnum:randnum+spl,-1])
    y_test.extend(data.values[0:randnum-1,-1])
    y_test.extend(data.values[randnum+spl:,-1])

X_train = X_train[1:]
X_test = X_test[1:]

X_train = pd.DataFrame(data=X_train,columns=dataset.columns[:-3])
X_test= pd.DataFrame(data=X_test,columns=dataset.columns[:-3])
del dataset['delay']
del dataset['capture']

# %%
mms = preprocessing.MinMaxScaler()
X_train = mms.fit_transform(X_train)
X_test = mms.transform(X_test)

# %%
y_test = list(map(int,y_test))
y_train = list(map(int,y_train))
Ratio10(y_test,'y_test')
Ratio10(y_train,'y_train')
# Out:
# y_test
# Counter({0: 304189, 1: 3763})
# 0: 98.78%
# 1: 1.22%
#
# y_train
# Counter({0: 1122658, 1: 109266})
# 0: 91.13%
# 1: 8.87%

# %%
METRICS = [
    tf.keras.metrics.TruePositives(name='tp'),
    tf.keras.metrics.FalsePositives(name='fp'),
    tf.keras.metrics.TrueNegatives(name='tn'),
    tf.keras.metrics.FalseNegatives(name='fn'),
    tf.keras.metrics.BinaryAccuracy(name='accuracy'),
    tf.keras.metrics.Precision(name='precision'),
    tf.keras.metrics.Recall(name='recall'),
    tf.keras.metrics.AUC(name='auc'),
]

EPOCHS = 100
BATCH_SIZE = 2048

early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', 
                                                  verbose=1,
                                                  patience=10,
                                                  mode='max',
                                                  restore_best_weights=True)

# %%
n_features = X_train.shape[1]
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# 1231924/1231924 [==============================] - 4s 3us/step
# Loss: 0.6867

# %%
initial_bias = np.log([pos/neg])
print(initial_bias)
# Out:
# [-2.53560092]

# %%
model = keras.Sequential()
model.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(1,activation='sigmoid',bias_initializer=keras.initializers.Constant(initial_bias)))
print('Built NN...')
model.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model.summary()
print('Compiled NN...')
# Out:
# Built NN...
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...

# %%
model.predict(X_train[:10])
results = model.evaluate(X_train, y_train, batch_size=BATCH_SIZE, verbose=1)
print("Loss: {:0.4f}".format(results[0]))
# Out:
# 1231924/1231924 [==============================] - 4s 4us/step
# Loss: 0.3074

# %%
initial_weights = os.path.join(tempfile.mkdtemp(),'initial_weights')
model.save_weights(initial_weights)

# %%
model_baseline = keras.Sequential()
model_baseline.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model_baseline.add(keras.layers.Dropout(0.5))
model_baseline.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model_baseline.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model_baseline.summary()
print('Compiled NN...')

baseline_history = model_baseline.fit(X_train,
                             y_train,
                             batch_size=BATCH_SIZE,
                             epochs=EPOCHS,
                             callbacks = [early_stopping],
                             validation_split=0.2
                             )
# Out:
# Built NN...
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_5 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.3589 - tp: 25690.5371 - fp: 241383.9688 - tn: 2464586.2500 - fn: 226775.9531 - accuracy: 0.8411 - precision: 0.0962 - recall: 0.1022 - auc: 0.5011 - val_loss: 0.5226 - val_tp: 25956.0000 - val_fp: 244963.4375 - val_tn: 3023546.5000 - val_fn: 279838.2812 - val_accuracy: 0.8532 - val_precision: 0.0958 - val_recall: 0.0850 - val_auc: 0.4983
# Epoch 2/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2787 - tp: 25961.7148 - fp: 245008.3750 - tn: 3583719.7500 - fn: 335669.8438 - accuracy: 0.8611 - precision: 0.0958 - recall: 0.0720 - auc: 0.4948 - val_loss: 0.5124 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 4146138.5000 - val_fn: 389097.1562 - val_accuracy: 0.8681 - val_precision: 0.0958 - val_recall: 0.0626 - val_auc: 0.4962
# Epoch 3/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2717 - tp: 25963.0000 - fp: 245026.1250 - tn: 4706150.5000 - fn: 445141.8438 - accuracy: 0.8726 - precision: 0.0958 - recall: 0.0552 - auc: 0.4961 - val_loss: 0.5078 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 5268794.0000 - val_fn: 498363.3438 - val_accuracy: 0.8769 - val_precision: 0.0958 - val_recall: 0.0495 - val_auc: 0.4976
# Epoch 4/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2671 - tp: 25963.0000 - fp: 245026.1250 - tn: 5828908.0000 - fn: 554312.3750 - accuracy: 0.8798 - precision: 0.0958 - recall: 0.0448 - auc: 0.4986 - val_loss: 0.5022 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 6391457.5000 - val_fn: 607629.2500 - val_accuracy: 0.8827 - val_precision: 0.0958 - val_recall: 0.0410 - val_auc: 0.4998
# Epoch 5/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2628 - tp: 25963.0000 - fp: 245026.1250 - tn: 6951669.0000 - fn: 663473.4375 - accuracy: 0.8847 - precision: 0.0958 - recall: 0.0377 - auc: 0.5011 - val_loss: 0.5018 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 7514109.5000 - val_fn: 716895.0625 - val_accuracy: 0.8869 - val_precision: 0.0958 - val_recall: 0.0350 - val_auc: 0.5023
# Epoch 6/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2600 - tp: 25963.0000 - fp: 245026.1250 - tn: 8074383.0000 - fn: 772683.8750 - accuracy: 0.8883 - precision: 0.0958 - recall: 0.0325 - auc: 0.5035 - val_loss: 0.4974 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 8636771.0000 - val_fn: 826161.1875 - val_accuracy: 0.8900 - val_precision: 0.0958 - val_recall: 0.0305 - val_auc: 0.5043
# Epoch 7/100
# 985539/985539 [==============================] - 6s 7us/step - loss: 0.2574 - tp: 25963.0000 - fp: 245026.1250 - tn: 9196958.0000 - fn: 882032.0625 - accuracy: 0.8911 - precision: 0.0958 - recall: 0.0286 - auc: 0.5056 - val_loss: 0.5018 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 9759431.0000 - val_fn: 935427.0625 - val_accuracy: 0.8924 - val_precision: 0.0958 - val_recall: 0.0270 - val_auc: 0.5061
# Epoch 8/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2555 - tp: 25963.0000 - fp: 245026.1250 - tn: 10319612.0000 - fn: 991304.1250 - accuracy: 0.8932 - precision: 0.0958 - recall: 0.0255 - auc: 0.5068 - val_loss: 0.5040 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 10882085.0000 - val_fn: 1044693.2500 - val_accuracy: 0.8943 - val_precision: 0.0958 - val_recall: 0.0243 - val_auc: 0.5073
# Epoch 9/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2537 - tp: 25963.0000 - fp: 245026.1250 - tn: 11442153.0000 - fn: 1100686.5000 - accuracy: 0.8950 - precision: 0.0958 - recall: 0.0231 - auc: 0.5080 - val_loss: 0.5007 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 12004740.0000 - val_fn: 1153959.2500 - val_accuracy: 0.8958 - val_precision: 0.0958 - val_recall: 0.0220 - val_auc: 0.5086
# Epoch 10/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2521 - tp: 25963.0000 - fp: 245026.1250 - tn: 12564885.0000 - fn: 1209877.1250 - accuracy: 0.8964 - precision: 0.0958 - recall: 0.0210 - auc: 0.5095 - val_loss: 0.5007 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 13127403.0000 - val_fn: 1263226.3750 - val_accuracy: 0.8971 - val_precision: 0.0958 - val_recall: 0.0201 - val_auc: 0.5101
# Epoch 11/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2510 - tp: 25963.0000 - fp: 245026.1250 - tn: 13687484.0000 - fn: 1319200.7500 - accuracy: 0.8976 - precision: 0.0958 - recall: 0.0193 - auc: 0.5111 - val_loss: 0.5008 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 14250063.0000 - val_fn: 1372491.3750 - val_accuracy: 0.8982 - val_precision: 0.0958 - val_recall: 0.0186 - val_auc: 0.5117
# Epoch 12/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2502 - tp: 25963.0000 - fp: 245026.1250 - tn: 14809968.0000 - fn: 1428644.7500 - accuracy: 0.8986 - precision: 0.0958 - recall: 0.0179 - auc: 0.5126 - val_loss: 0.5018 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 15372722.0000 - val_fn: 1481757.3750 - val_accuracy: 0.8992 - val_precision: 0.0958 - val_recall: 0.0172 - val_auc: 0.5131
# Epoch 13/100
#  - ETA: 5s - loss: 0.2446 - tp: 25963.0000 - fp: 245027.0000 - tn: 15498942.0000 - fn: 1505675.8750 - accuracy: 0.8987 - precision: 0.0958 - recall: 0.0170 - auc: 0.5135
# Epoch 14/100
# 985539/985539 [==============================] - 7s 7us/step - loss: 0.2493 - tp: 25963.0000 - fp: 245026.1250 - tn: 17055584.0000 - fn: 1646868.6250 - accuracy: 0.9003 - precision: 0.0958 - recall: 0.0155 - auc: 0.5155 - val_loss: 0.5034 - val_tp: 25963.0000 - val_fp: 245027.4375 - val_tn: 17618032.0000 - val_fn: 1700289.0000 - val_accuracy: 0.9007 - val_precision: 0.0958 - val_recall: 0.0150 - val_auc: 0.5160
# Epoch 15/100
#  - ETA: 4s - loss: 0.2500 - tp: 25963.0000 - fp: 245027.0000 - tn: 17745170.0000 - fn: 1724308.1250 - accuracy: 0.9002 - precision: 0.0958 - recall: 0.0148 - auc: 0.5162
# Epoch 16/100
#  - ETA: 1s - loss: 0.2486 - tp: 25972.6406 - fp: 245056.8750 - tn: 19165372.0000 - fn: 1855513.7500 - accuracy: 0.9013 - precision: 0.0958 - recall: 0.0138 - auc: 0.5180
# Epoch 17/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2486 - tp: 25983.0938 - fp: 245091.9219 - tn: 20423616.0000 - fn: 1974541.6250 - accuracy: 0.9021 - precision: 0.0959 - recall: 0.0130 - auc: 0.5195 - val_loss: 0.5030 - val_tp: 25988.0000 - val_fp: 245108.0000 - val_tn: 20985936.0000 - val_fn: 2028062.1250 - val_accuracy: 0.9024 - val_precision: 0.0959 - val_recall: 0.0127 - val_auc: 0.5201
# Epoch 18/100
#  - ETA: 5s - loss: 0.2524 - tp: 25990.3223 - fp: 245114.9062 - tn: 21115858.0000 - fn: 2052369.6250 - accuracy: 0.9020 - precision: 0.0959 - recall: 0.0125 - auc: 0.5204
# Epoch 19/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2485 - tp: 26095.8555 - fp: 245333.8125 - tn: 22668632.0000 - fn: 2193053.0000 - accuracy: 0.9030 - precision: 0.0961 - recall: 0.0118 - auc: 0.5224 - val_loss: 0.5050 - val_tp: 26107.0000 - val_fp: 245366.0000 - val_tn: 23231018.0000 - val_fn: 2246475.7500 - val_accuracy: 0.9032 - val_precision: 0.0962 - val_recall: 0.0115 - val_auc: 0.5228
# Epoch 20/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2484 - tp: 26107.0156 - fp: 245367.4375 - tn: 23791092.0000 - fn: 2302473.2500 - accuracy: 0.9034 - precision: 0.0962 - recall: 0.0112 - auc: 0.5235 - val_loss: 0.5048 - val_tp: 26108.0000 - val_fp: 245367.4375 - val_tn: 24353690.0000 - val_fn: 2355740.5000 - val_accuracy: 0.9036 - val_precision: 0.0962 - val_recall: 0.0110 - val_auc: 0.5240
# Epoch 21/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2484 - tp: 26160.4277 - fp: 245467.1250 - tn: 24913714.0000 - fn: 2411608.7500 - accuracy: 0.9037 - precision: 0.0963 - recall: 0.0107 - auc: 0.5247 - val_loss: 0.5054 - val_tp: 26201.0000 - val_fp: 245548.5625 - val_tn: 25476132.0000 - val_fn: 2464912.5000 - val_accuracy: 0.9039 - val_precision: 0.0964 - val_recall: 0.0105 - val_auc: 0.5251
# Epoch 22/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2484 - tp: 26236.4883 - fp: 245612.9531 - tn: 26036286.0000 - fn: 2520737.7500 - accuracy: 0.9040 - precision: 0.0965 - recall: 0.0103 - auc: 0.5258 - val_loss: 0.5061 - val_tp: 26257.0000 - val_fp: 245662.0000 - val_tn: 26598682.0000 - val_fn: 2574123.2500 - val_accuracy: 0.9042 - val_precision: 0.0966 - val_recall: 0.0101 - val_auc: 0.5262
# Epoch 23/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2484 - tp: 26291.7852 - fp: 245738.2344 - tn: 27158706.0000 - fn: 2630027.5000 - accuracy: 0.9043 - precision: 0.0967 - recall: 0.0099 - auc: 0.5268 - val_loss: 0.5044 - val_tp: 26306.0000 - val_fp: 245770.0000 - val_tn: 27721220.0000 - val_fn: 2683340.0000 - val_accuracy: 0.9045 - val_precision: 0.0967 - val_recall: 0.0097 - val_auc: 0.5272
# Epoch 24/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2483 - tp: 26319.3926 - fp: 245791.0312 - tn: 28281370.0000 - fn: 2739196.7500 - accuracy: 0.9046 - precision: 0.0967 - recall: 0.0095 - auc: 0.5278 - val_loss: 0.5054 - val_tp: 26364.0000 - val_fp: 245856.0000 - val_tn: 28843788.0000 - val_fn: 2792548.5000 - val_accuracy: 0.9048 - val_precision: 0.0968 - val_recall: 0.0094 - val_auc: 0.5282
# Epoch 25/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2483 - tp: 26431.7734 - fp: 245962.7656 - tn: 29403736.0000 - fn: 2848461.7500 - accuracy: 0.9049 - precision: 0.0970 - recall: 0.0092 - auc: 0.5287 - val_loss: 0.5040 - val_tp: 26472.0000 - val_fp: 246042.0000 - val_tn: 29966230.0000 - val_fn: 2901705.7500 - val_accuracy: 0.9050 - val_precision: 0.0971 - val_recall: 0.0090 - val_auc: 0.5291
# Epoch 26/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2484 - tp: 26514.3047 - fp: 246124.7031 - tn: 30526192.0000 - fn: 2957664.5000 - accuracy: 0.9051 - precision: 0.0973 - recall: 0.0089 - auc: 0.5297 - val_loss: 0.5058 - val_tp: 26559.0000 - val_fp: 246215.4375 - val_tn: 31088710.0000 - val_fn: 3010885.7500 - val_accuracy: 0.9052 - val_precision: 0.0974 - val_recall: 0.0087 - val_auc: 0.5301
# Epoch 27/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2483 - tp: 26626.7051 - fp: 246311.9219 - tn: 31648680.0000 - fn: 3066796.5000 - accuracy: 0.9053 - precision: 0.0976 - recall: 0.0086 - auc: 0.5306 - val_loss: 0.5051 - val_tp: 26679.0000 - val_fp: 246404.5625 - val_tn: 32211156.0000 - val_fn: 3120033.2500 - val_accuracy: 0.9054 - val_precision: 0.0977 - val_recall: 0.0085 - val_auc: 0.5309
# Epoch 28/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2484 - tp: 26733.2070 - fp: 246494.0312 - tn: 32771210.0000 - fn: 3175911.5000 - accuracy: 0.9055 - precision: 0.0978 - recall: 0.0083 - auc: 0.5314 - val_loss: 0.5073 - val_tp: 26790.0000 - val_fp: 246590.0000 - val_tn: 33333650.0000 - val_fn: 3229186.7500 - val_accuracy: 0.9056 - val_precision: 0.0980 - val_recall: 0.0082 - val_auc: 0.5316
# Epoch 29/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2484 - tp: 26845.6328 - fp: 246691.6875 - tn: 33893800.0000 - fn: 3284921.7500 - accuracy: 0.9057 - precision: 0.0981 - recall: 0.0081 - auc: 0.5321 - val_loss: 0.5058 - val_tp: 26898.0000 - val_fp: 246780.5625 - val_tn: 34456104.0000 - val_fn: 3338345.0000 - val_accuracy: 0.9058 - val_precision: 0.0983 - val_recall: 0.0080 - val_auc: 0.5323
# Epoch 30/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2483 - tp: 26957.2207 - fp: 246875.4688 - tn: 35016116.0000 - fn: 3394204.7500 - accuracy: 0.9059 - precision: 0.0984 - recall: 0.0079 - auc: 0.5328 - val_loss: 0.5050 - val_tp: 27022.0000 - val_fp: 246963.4375 - val_tn: 35578524.0000 - val_fn: 3447488.7500 - val_accuracy: 0.9060 - val_precision: 0.0986 - val_recall: 0.0078 - val_auc: 0.5330
# Epoch 31/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2483 - tp: 27081.3105 - fp: 247050.7812 - tn: 36138600.0000 - fn: 3503339.5000 - accuracy: 0.9060 - precision: 0.0988 - recall: 0.0077 - auc: 0.5335 - val_loss: 0.5048 - val_tp: 27140.0000 - val_fp: 247148.5625 - val_tn: 36701008.0000 - val_fn: 3556633.7500 - val_accuracy: 0.9062 - val_precision: 0.0989 - val_recall: 0.0076 - val_auc: 0.5337
# Epoch 32/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2483 - tp: 27196.7617 - fp: 247229.5312 - tn: 37260952.0000 - fn: 3612589.0000 - accuracy: 0.9062 - precision: 0.0991 - recall: 0.0075 - auc: 0.5341 - val_loss: 0.5070 - val_tp: 27250.0000 - val_fp: 247307.4375 - val_tn: 37823476.0000 - val_fn: 3665792.7500 - val_accuracy: 0.9063 - val_precision: 0.0993 - val_recall: 0.0074 - val_auc: 0.5343
# Epoch 33/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2483 - tp: 27309.7344 - fp: 247393.9219 - tn: 38383504.0000 - fn: 3721639.5000 - accuracy: 0.9063 - precision: 0.0994 - recall: 0.0073 - auc: 0.5347 - val_loss: 0.5063 - val_tp: 27364.0000 - val_fp: 247486.0000 - val_tn: 38945876.0000 - val_fn: 3774943.7500 - val_accuracy: 0.9064 - val_precision: 0.0996 - val_recall: 0.0072 - val_auc: 0.5349
# Epoch 34/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2483 - tp: 27429.4727 - fp: 247575.9375 - tn: 39505944.0000 - fn: 3830775.5000 - accuracy: 0.9065 - precision: 0.0997 - recall: 0.0071 - auc: 0.5353 - val_loss: 0.5047 - val_tp: 27486.0000 - val_fp: 247674.0000 - val_tn: 40068420.0000 - val_fn: 3884087.2500 - val_accuracy: 0.9066 - val_precision: 0.0999 - val_recall: 0.0070 - val_auc: 0.5355
# Epoch 35/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2483 - tp: 27541.2188 - fp: 247768.7656 - tn: 40628472.0000 - fn: 3939921.5000 - accuracy: 0.9066 - precision: 0.1000 - recall: 0.0069 - auc: 0.5358 - val_loss: 0.5068 - val_tp: 27599.0000 - val_fp: 247871.4375 - val_tn: 41190844.0000 - val_fn: 3993241.0000 - val_accuracy: 0.9067 - val_precision: 0.1002 - val_recall: 0.0069 - val_auc: 0.5359
# Epoch 36/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2484 - tp: 27654.0566 - fp: 247962.0312 - tn: 41750844.0000 - fn: 4049180.0000 - accuracy: 0.9067 - precision: 0.1003 - recall: 0.0068 - auc: 0.5362 - val_loss: 0.5049 - val_tp: 27702.0000 - val_fp: 248044.0000 - val_tn: 42313344.0000 - val_fn: 4102402.0000 - val_accuracy: 0.9068 - val_precision: 0.1005 - val_recall: 0.0067 - val_auc: 0.5364
# Epoch 37/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 27754.7891 - fp: 248123.7969 - tn: 42873288.0000 - fn: 4158389.5000 - accuracy: 0.9068 - precision: 0.1006 - recall: 0.0066 - auc: 0.5367 - val_loss: 0.5059 - val_tp: 27812.0000 - val_fp: 248216.0000 - val_tn: 43435852.0000 - val_fn: 4211558.0000 - val_accuracy: 0.9069 - val_precision: 0.1008 - val_recall: 0.0066 - val_auc: 0.5369
# Epoch 38/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 27853.6113 - fp: 248299.3125 - tn: 43995908.0000 - fn: 4267396.0000 - accuracy: 0.9070 - precision: 0.1009 - recall: 0.0065 - auc: 0.5372 - val_loss: 0.5037 - val_tp: 27902.0000 - val_fp: 248399.4375 - val_tn: 44558276.0000 - val_fn: 4320735.5000 - val_accuracy: 0.9070 - val_precision: 0.1010 - val_recall: 0.0064 - val_auc: 0.5374
# Epoch 39/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2484 - tp: 27960.5586 - fp: 248497.7812 - tn: 45118368.0000 - fn: 4376592.0000 - accuracy: 0.9071 - precision: 0.1011 - recall: 0.0063 - auc: 0.5378 - val_loss: 0.5066 - val_tp: 28024.0000 - val_fp: 248596.5625 - val_tn: 45680776.0000 - val_fn: 4429879.5000 - val_accuracy: 0.9071 - val_precision: 0.1013 - val_recall: 0.0063 - val_auc: 0.5379
# Epoch 40/100
#  - ETA: 0s - loss: 0.2485 - tp: 28054.9512 - fp: 248657.3594 - tn: 46153180.0000 - fn: 4479196.5000 - accuracy: 0.9071 - precision: 0.1014 - recall: 0.0062 - auc: 0.5382
# Epoch 41/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 28168.0449 - fp: 248821.4062 - tn: 47363192.0000 - fn: 4595035.5000 - accuracy: 0.9073 - precision: 0.1017 - recall: 0.0061 - auc: 0.5386 - val_loss: 0.5055 - val_tp: 28213.0000 - val_fp: 248890.0000 - val_tn: 47925764.0000 - val_fn: 4648220.0000 - val_accuracy: 0.9073 - val_precision: 0.1018 - val_recall: 0.0060 - val_auc: 0.5387
# Epoch 42/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 28243.4590 - fp: 248940.2812 - tn: 48485856.0000 - fn: 4704101.5000 - accuracy: 0.9074 - precision: 0.1019 - recall: 0.0060 - auc: 0.5390 - val_loss: 0.5064 - val_tp: 28273.0000 - val_fp: 249000.0000 - val_tn: 49048328.0000 - val_fn: 4757429.5000 - val_accuracy: 0.9074 - val_precision: 0.1020 - val_recall: 0.0059 - val_auc: 0.5391
# Epoch 43/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 28301.5352 - fp: 249045.6719 - tn: 49608452.0000 - fn: 4813249.0000 - accuracy: 0.9074 - precision: 0.1020 - recall: 0.0058 - auc: 0.5394 - val_loss: 0.5055 - val_tp: 28331.0000 - val_fp: 249099.4375 - val_tn: 50170796.0000 - val_fn: 4866634.5000 - val_accuracy: 0.9075 - val_precision: 0.1021 - val_recall: 0.0058 - val_auc: 0.5395
# Epoch 44/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 28360.8965 - fp: 249141.7656 - tn: 50730876.0000 - fn: 4922556.5000 - accuracy: 0.9075 - precision: 0.1022 - recall: 0.0057 - auc: 0.5397 - val_loss: 0.5054 - val_tp: 28387.0000 - val_fp: 249190.0000 - val_tn: 51293388.0000 - val_fn: 4975842.5000 - val_accuracy: 0.9076 - val_precision: 0.1023 - val_recall: 0.0057 - val_auc: 0.5399
# Epoch 45/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2483 - tp: 28414.3672 - fp: 249236.1094 - tn: 51853612.0000 - fn: 5031605.0000 - accuracy: 0.9076 - precision: 0.1023 - recall: 0.0056 - auc: 0.5401 - val_loss: 0.5034 - val_tp: 28444.0000 - val_fp: 249282.0000 - val_tn: 52415928.0000 - val_fn: 5085056.5000 - val_accuracy: 0.9077 - val_precision: 0.1024 - val_recall: 0.0056 - val_auc: 0.5402
# Epoch 46/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 28471.5410 - fp: 249331.8125 - tn: 52976084.0000 - fn: 5140924.5000 - accuracy: 0.9077 - precision: 0.1025 - recall: 0.0055 - auc: 0.5405 - val_loss: 0.5050 - val_tp: 28494.0000 - val_fp: 249387.4375 - val_tn: 53538524.0000 - val_fn: 5194268.5000 - val_accuracy: 0.9077 - val_precision: 0.1025 - val_recall: 0.0055 - val_auc: 0.5406
# Epoch 47/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 28524.9414 - fp: 249448.8906 - tn: 54098592.0000 - fn: 5250145.0000 - accuracy: 0.9078 - precision: 0.1026 - recall: 0.0054 - auc: 0.5409 - val_loss: 0.5072 - val_tp: 28555.0000 - val_fp: 249504.5625 - val_tn: 54661004.0000 - val_fn: 5303479.0000 - val_accuracy: 0.9078 - val_precision: 0.1027 - val_recall: 0.0054 - val_auc: 0.5408
# Epoch 48/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 28583.4336 - fp: 249547.3906 - tn: 55221124.0000 - fn: 5359344.5000 - accuracy: 0.9078 - precision: 0.1028 - recall: 0.0053 - auc: 0.5409 - val_loss: 0.5073 - val_tp: 28614.0000 - val_fp: 249591.4375 - val_tn: 55783576.0000 - val_fn: 5412681.0000 - val_accuracy: 0.9079 - val_precision: 0.1029 - val_recall: 0.0053 - val_auc: 0.5409
# Epoch 49/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 28641.2207 - fp: 249641.7969 - tn: 56343620.0000 - fn: 5468590.0000 - accuracy: 0.9079 - precision: 0.1029 - recall: 0.0052 - auc: 0.5410 - val_loss: 0.5049 - val_tp: 28668.0000 - val_fp: 249686.0000 - val_tn: 56906080.0000 - val_fn: 5521891.5000 - val_accuracy: 0.9080 - val_precision: 0.1030 - val_recall: 0.0052 - val_auc: 0.5411
# Epoch 50/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 28700.1562 - fp: 249727.7500 - tn: 57466248.0000 - fn: 5577722.5000 - accuracy: 0.9080 - precision: 0.1031 - recall: 0.0051 - auc: 0.5413 - val_loss: 0.5031 - val_tp: 28731.0000 - val_fp: 249768.5625 - val_tn: 58028716.0000 - val_fn: 5631101.0000 - val_accuracy: 0.9080 - val_precision: 0.1032 - val_recall: 0.0051 - val_auc: 0.5414
# Epoch 51/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 28758.7734 - fp: 249812.9531 - tn: 58588772.0000 - fn: 5686963.0000 - accuracy: 0.9080 - precision: 0.1032 - recall: 0.0050 - auc: 0.5417 - val_loss: 0.5048 - val_tp: 28789.0000 - val_fp: 249868.5625 - val_tn: 59151204.0000 - val_fn: 5740304.5000 - val_accuracy: 0.9081 - val_precision: 0.1033 - val_recall: 0.0050 - val_auc: 0.5417
# Epoch 52/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 28813.3945 - fp: 249926.9062 - tn: 59711368.0000 - fn: 5796131.5000 - accuracy: 0.9081 - precision: 0.1034 - recall: 0.0049 - auc: 0.5420 - val_loss: 0.5056 - val_tp: 28841.0000 - val_fp: 249968.5625 - val_tn: 60273840.0000 - val_fn: 5849524.5000 - val_accuracy: 0.9081 - val_precision: 0.1034 - val_recall: 0.0049 - val_auc: 0.5420
# Epoch 53/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 28871.4688 - fp: 250006.7344 - tn: 60834028.0000 - fn: 5905277.5000 - accuracy: 0.9081 - precision: 0.1035 - recall: 0.0049 - auc: 0.5422 - val_loss: 0.5048 - val_tp: 28899.0000 - val_fp: 250048.0000 - val_tn: 61396336.0000 - val_fn: 5958726.0000 - val_accuracy: 0.9082 - val_precision: 0.1036 - val_recall: 0.0048 - val_auc: 0.5423
# Epoch 54/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 28932.9180 - fp: 250092.7031 - tn: 61956484.0000 - fn: 6014573.0000 - accuracy: 0.9082 - precision: 0.1037 - recall: 0.0048 - auc: 0.5425 - val_loss: 0.5031 - val_tp: 28965.0000 - val_fp: 250136.5625 - val_tn: 62518932.0000 - val_fn: 6067925.0000 - val_accuracy: 0.9083 - val_precision: 0.1038 - val_recall: 0.0048 - val_auc: 0.5426
# Epoch 55/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 28996.3340 - fp: 250179.0156 - tn: 63078876.0000 - fn: 6123944.5000 - accuracy: 0.9083 - precision: 0.1039 - recall: 0.0047 - auc: 0.5428 - val_loss: 0.5072 - val_tp: 29026.0000 - val_fp: 250224.0000 - val_tn: 63641476.0000 - val_fn: 6177135.0000 - val_accuracy: 0.9083 - val_precision: 0.1039 - val_recall: 0.0047 - val_auc: 0.5429
# Epoch 56/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 29058.8926 - fp: 250276.7500 - tn: 64201524.0000 - fn: 6233051.5000 - accuracy: 0.9083 - precision: 0.1040 - recall: 0.0046 - auc: 0.5430 - val_loss: 0.5050 - val_tp: 29093.0000 - val_fp: 250332.0000 - val_tn: 64763964.0000 - val_fn: 6286334.5000 - val_accuracy: 0.9084 - val_precision: 0.1041 - val_recall: 0.0046 - val_auc: 0.5431
# Epoch 57/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 29125.3848 - fp: 250383.4375 - tn: 65324020.0000 - fn: 6342270.0000 - accuracy: 0.9084 - precision: 0.1042 - recall: 0.0046 - auc: 0.5433 - val_loss: 0.5048 - val_tp: 29152.0000 - val_fp: 250431.4375 - val_tn: 65886548.0000 - val_fn: 6395536.5000 - val_accuracy: 0.9084 - val_precision: 0.1043 - val_recall: 0.0045 - val_auc: 0.5434
# Epoch 58/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2481 - tp: 29176.4805 - fp: 250475.5469 - tn: 66446552.0000 - fn: 6451525.0000 - accuracy: 0.9084 - precision: 0.1043 - recall: 0.0045 - auc: 0.5435 - val_loss: 0.5053 - val_tp: 29200.0000 - val_fp: 250516.0000 - val_tn: 67009056.0000 - val_fn: 6504760.5000 - val_accuracy: 0.9085 - val_precision: 0.1044 - val_recall: 0.0045 - val_auc: 0.5436
# Epoch 59/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 29229.8711 - fp: 250574.4375 - tn: 67569288.0000 - fn: 6560544.0000 - accuracy: 0.9085 - precision: 0.1045 - recall: 0.0044 - auc: 0.5438 - val_loss: 0.5048 - val_tp: 29259.0000 - val_fp: 250627.4375 - val_tn: 68131656.0000 - val_fn: 6613963.5000 - val_accuracy: 0.9085 - val_precision: 0.1045 - val_recall: 0.0044 - val_auc: 0.5439
# Epoch 60/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 29285.1289 - fp: 250666.6562 - tn: 68691888.0000 - fn: 6669757.0000 - accuracy: 0.9085 - precision: 0.1046 - recall: 0.0044 - auc: 0.5440 - val_loss: 0.5049 - val_tp: 29311.0000 - val_fp: 250708.0000 - val_tn: 69254352.0000 - val_fn: 6723174.0000 - val_accuracy: 0.9085 - val_precision: 0.1047 - val_recall: 0.0043 - val_auc: 0.5441
# Epoch 61/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 29340.5059 - fp: 250757.6094 - tn: 69814384.0000 - fn: 6779103.0000 - accuracy: 0.9085 - precision: 0.1048 - recall: 0.0043 - auc: 0.5443 - val_loss: 0.5056 - val_tp: 29372.0000 - val_fp: 250798.0000 - val_tn: 70376912.0000 - val_fn: 6832382.0000 - val_accuracy: 0.9086 - val_precision: 0.1048 - val_recall: 0.0043 - val_auc: 0.5443
# Epoch 62/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2481 - tp: 29399.5723 - fp: 250834.8281 - tn: 70936960.0000 - fn: 6888317.0000 - accuracy: 0.9086 - precision: 0.1049 - recall: 0.0042 - auc: 0.5445 - val_loss: 0.5061 - val_tp: 29431.0000 - val_fp: 250880.5625 - val_tn: 71499480.0000 - val_fn: 6941587.0000 - val_accuracy: 0.9086 - val_precision: 0.1050 - val_recall: 0.0042 - val_auc: 0.5445
# Epoch 63/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 29462.8379 - fp: 250928.8906 - tn: 72059624.0000 - fn: 6997372.5000 - accuracy: 0.9086 - precision: 0.1051 - recall: 0.0042 - auc: 0.5447 - val_loss: 0.5044 - val_tp: 29495.0000 - val_fp: 250979.4375 - val_tn: 72621992.0000 - val_fn: 7050789.0000 - val_accuracy: 0.9087 - val_precision: 0.1052 - val_recall: 0.0042 - val_auc: 0.5447
# Epoch 64/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 29521.1875 - fp: 251022.2812 - tn: 73182032.0000 - fn: 7106736.0000 - accuracy: 0.9087 - precision: 0.1052 - recall: 0.0041 - auc: 0.5449 - val_loss: 0.5058 - val_tp: 29548.0000 - val_fp: 251064.0000 - val_tn: 73744584.0000 - val_fn: 7160007.0000 - val_accuracy: 0.9087 - val_precision: 0.1053 - val_recall: 0.0041 - val_auc: 0.5449
# Epoch 65/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 29567.5977 - fp: 251116.0469 - tn: 74304504.0000 - fn: 7216011.0000 - accuracy: 0.9087 - precision: 0.1053 - recall: 0.0041 - auc: 0.5449 - val_loss: 0.5059 - val_tp: 29595.0000 - val_fp: 251167.4375 - val_tn: 74867128.0000 - val_fn: 7269221.0000 - val_accuracy: 0.9087 - val_precision: 0.1054 - val_recall: 0.0041 - val_auc: 0.5450
# Epoch 66/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 29624.3262 - fp: 251215.6094 - tn: 75427112.0000 - fn: 7325188.0000 - accuracy: 0.9087 - precision: 0.1055 - recall: 0.0040 - auc: 0.5451 - val_loss: 0.5055 - val_tp: 29650.0000 - val_fp: 251264.5625 - val_tn: 75989600.0000 - val_fn: 7378433.5000 - val_accuracy: 0.9088 - val_precision: 0.1055 - val_recall: 0.0040 - val_auc: 0.5452
# Epoch 67/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2481 - tp: 29683.0293 - fp: 251312.7969 - tn: 76549728.0000 - fn: 7434316.0000 - accuracy: 0.9088 - precision: 0.1056 - recall: 0.0040 - auc: 0.5453 - val_loss: 0.5051 - val_tp: 29717.0000 - val_fp: 251363.4375 - val_tn: 77112168.0000 - val_fn: 7487634.5000 - val_accuracy: 0.9088 - val_precision: 0.1057 - val_recall: 0.0040 - val_auc: 0.5454
# Epoch 68/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2481 - tp: 29754.9434 - fp: 251409.3281 - tn: 77672392.0000 - fn: 7543467.0000 - accuracy: 0.9088 - precision: 0.1058 - recall: 0.0039 - auc: 0.5455 - val_loss: 0.5048 - val_tp: 29789.0000 - val_fp: 251448.0000 - val_tn: 78234864.0000 - val_fn: 7596822.5000 - val_accuracy: 0.9089 - val_precision: 0.1059 - val_recall: 0.0039 - val_auc: 0.5456
# Epoch 69/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 29817.7188 - fp: 251491.6094 - tn: 78795000.0000 - fn: 7652677.0000 - accuracy: 0.9089 - precision: 0.1060 - recall: 0.0039 - auc: 0.5457 - val_loss: 0.5051 - val_tp: 29847.0000 - val_fp: 251531.4375 - val_tn: 79357384.0000 - val_fn: 7706038.5000 - val_accuracy: 0.9089 - val_precision: 0.1061 - val_recall: 0.0039 - val_auc: 0.5458
# Epoch 70/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2481 - tp: 29877.4414 - fp: 251576.6562 - tn: 79917456.0000 - fn: 7761850.5000 - accuracy: 0.9089 - precision: 0.1062 - recall: 0.0038 - auc: 0.5459 - val_loss: 0.5048 - val_tp: 29904.0000 - val_fp: 251614.0000 - val_tn: 80479760.0000 - val_fn: 7815248.0000 - val_accuracy: 0.9089 - val_precision: 0.1062 - val_recall: 0.0038 - val_auc: 0.5459
# Epoch 71/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 29934.4746 - fp: 251659.3906 - tn: 81039760.0000 - fn: 7871221.5000 - accuracy: 0.9089 - precision: 0.1063 - recall: 0.0038 - auc: 0.5461 - val_loss: 0.5054 - val_tp: 29957.0000 - val_fp: 251714.0000 - val_tn: 81602296.0000 - val_fn: 7924453.0000 - val_accuracy: 0.9090 - val_precision: 0.1064 - val_recall: 0.0038 - val_auc: 0.5461
# Epoch 72/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 29983.2793 - fp: 251764.2812 - tn: 82162312.0000 - fn: 7980351.0000 - accuracy: 0.9090 - precision: 0.1064 - recall: 0.0037 - auc: 0.5463 - val_loss: 0.5035 - val_tp: 30010.0000 - val_fp: 251802.0000 - val_tn: 82724752.0000 - val_fn: 8033673.0000 - val_accuracy: 0.9090 - val_precision: 0.1065 - val_recall: 0.0037 - val_auc: 0.5463
# Epoch 73/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 30028.2012 - fp: 251845.7031 - tn: 83284928.0000 - fn: 8089501.0000 - accuracy: 0.9090 - precision: 0.1065 - recall: 0.0037 - auc: 0.5464 - val_loss: 0.5032 - val_tp: 30048.0000 - val_fp: 251891.4375 - val_tn: 83847408.0000 - val_fn: 8142902.5000 - val_accuracy: 0.9090 - val_precision: 0.1066 - val_recall: 0.0037 - val_auc: 0.5465
# Epoch 74/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 30075.5254 - fp: 251939.9844 - tn: 84407408.0000 - fn: 8198815.5000 - accuracy: 0.9090 - precision: 0.1066 - recall: 0.0037 - auc: 0.5466 - val_loss: 0.5059 - val_tp: 30097.0000 - val_fp: 251987.4375 - val_tn: 84969928.0000 - val_fn: 8252114.0000 - val_accuracy: 0.9090 - val_precision: 0.1067 - val_recall: 0.0036 - val_auc: 0.5466
# Epoch 75/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 30124.9023 - fp: 252032.9219 - tn: 85530168.0000 - fn: 8307890.0000 - accuracy: 0.9090 - precision: 0.1068 - recall: 0.0036 - auc: 0.5468 - val_loss: 0.5034 - val_tp: 30149.0000 - val_fp: 252070.0000 - val_tn: 86092568.0000 - val_fn: 8361334.5000 - val_accuracy: 0.9091 - val_precision: 0.1068 - val_recall: 0.0036 - val_auc: 0.5468
# Epoch 76/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 30166.8320 - fp: 252119.4219 - tn: 86652640.0000 - fn: 8417196.0000 - accuracy: 0.9091 - precision: 0.1069 - recall: 0.0036 - auc: 0.5470 - val_loss: 0.5047 - val_tp: 30189.0000 - val_fp: 252168.5625 - val_tn: 87215056.0000 - val_fn: 8470552.0000 - val_accuracy: 0.9091 - val_precision: 0.1069 - val_recall: 0.0036 - val_auc: 0.5470
# Epoch 77/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2481 - tp: 30219.4746 - fp: 252216.4844 - tn: 87775128.0000 - fn: 8526433.0000 - accuracy: 0.9091 - precision: 0.1070 - recall: 0.0035 - auc: 0.5472 - val_loss: 0.5054 - val_tp: 30246.0000 - val_fp: 252266.0000 - val_tn: 88337552.0000 - val_fn: 8579767.0000 - val_accuracy: 0.9091 - val_precision: 0.1071 - val_recall: 0.0035 - val_auc: 0.5472
# Epoch 78/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2481 - tp: 30278.5898 - fp: 252317.9688 - tn: 88897712.0000 - fn: 8635512.0000 - accuracy: 0.9091 - precision: 0.1071 - recall: 0.0035 - auc: 0.5473 - val_loss: 0.5043 - val_tp: 30312.0000 - val_fp: 252360.0000 - val_tn: 89460008.0000 - val_fn: 8688968.0000 - val_accuracy: 0.9092 - val_precision: 0.1072 - val_recall: 0.0035 - val_auc: 0.5473
# Epoch 79/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2481 - tp: 30346.5137 - fp: 252403.4531 - tn: 90020192.0000 - fn: 8744841.0000 - accuracy: 0.9092 - precision: 0.1073 - recall: 0.0035 - auc: 0.5475 - val_loss: 0.5047 - val_tp: 30382.0000 - val_fp: 252448.5625 - val_tn: 90582624.0000 - val_fn: 8798161.0000 - val_accuracy: 0.9092 - val_precision: 0.1074 - val_recall: 0.0034 - val_auc: 0.5475
# Epoch 80/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 30411.4473 - fp: 252482.4844 - tn: 91142800.0000 - fn: 8854004.0000 - accuracy: 0.9092 - precision: 0.1075 - recall: 0.0034 - auc: 0.5476 - val_loss: 0.5056 - val_tp: 30441.0000 - val_fp: 252522.0000 - val_tn: 91705240.0000 - val_fn: 8907367.0000 - val_accuracy: 0.9092 - val_precision: 0.1076 - val_recall: 0.0034 - val_auc: 0.5476
# Epoch 81/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 30472.4180 - fp: 252559.9062 - tn: 92265408.0000 - fn: 8963190.0000 - accuracy: 0.9092 - precision: 0.1077 - recall: 0.0034 - auc: 0.5478 - val_loss: 0.5038 - val_tp: 30500.0000 - val_fp: 252600.5625 - val_tn: 92827896.0000 - val_fn: 9016572.0000 - val_accuracy: 0.9092 - val_precision: 0.1077 - val_recall: 0.0034 - val_auc: 0.5478
# Epoch 82/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 30532.3906 - fp: 252645.4844 - tn: 93387992.0000 - fn: 9072430.0000 - accuracy: 0.9092 - precision: 0.1078 - recall: 0.0034 - auc: 0.5479 - val_loss: 0.5058 - val_tp: 30562.0000 - val_fp: 252696.5625 - val_tn: 93950440.0000 - val_fn: 9125777.0000 - val_accuracy: 0.9093 - val_precision: 0.1079 - val_recall: 0.0033 - val_auc: 0.5479
# Epoch 83/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 30589.8516 - fp: 252743.7969 - tn: 94510560.0000 - fn: 9181699.0000 - accuracy: 0.9093 - precision: 0.1080 - recall: 0.0033 - auc: 0.5480 - val_loss: 0.5051 - val_tp: 30624.0000 - val_fp: 252784.5625 - val_tn: 95073032.0000 - val_fn: 9234982.0000 - val_accuracy: 0.9093 - val_precision: 0.1081 - val_recall: 0.0033 - val_auc: 0.5480
# Epoch 84/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.2482 - tp: 30645.0762 - fp: 252817.1562 - tn: 95633088.0000 - fn: 9290980.0000 - accuracy: 0.9093 - precision: 0.1081 - recall: 0.0033 - auc: 0.5481 - val_loss: 0.5061 - val_tp: 30673.0000 - val_fp: 252859.4375 - val_tn: 96195712.0000 - val_fn: 9344197.0000 - val_accuracy: 0.9093 - val_precision: 0.1082 - val_recall: 0.0033 - val_auc: 0.5482
# Epoch 85/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2483 - tp: 30696.2051 - fp: 252896.7656 - tn: 96755824.0000 - fn: 9400072.0000 - accuracy: 0.9093 - precision: 0.1082 - recall: 0.0033 - auc: 0.5482 - val_loss: 0.5036 - val_tp: 30724.0000 - val_fp: 252943.4375 - val_tn: 97318184.0000 - val_fn: 9453418.0000 - val_accuracy: 0.9093 - val_precision: 0.1083 - val_recall: 0.0032 - val_auc: 0.5483
# Epoch 86/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 30759.6523 - fp: 253004.4219 - tn: 97878312.0000 - fn: 9509273.0000 - accuracy: 0.9093 - precision: 0.1084 - recall: 0.0032 - auc: 0.5484 - val_loss: 0.5048 - val_tp: 30795.0000 - val_fp: 253055.4375 - val_tn: 98440720.0000 - val_fn: 9562614.0000 - val_accuracy: 0.9094 - val_precision: 0.1085 - val_recall: 0.0032 - val_auc: 0.5484
# Epoch 87/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 30822.6953 - fp: 253107.2188 - tn: 99000816.0000 - fn: 9618459.0000 - accuracy: 0.9093 - precision: 0.1086 - recall: 0.0032 - auc: 0.5485 - val_loss: 0.5043 - val_tp: 30846.0000 - val_fp: 253152.0000 - val_tn: 99563248.0000 - val_fn: 9671823.0000 - val_accuracy: 0.9094 - val_precision: 0.1086 - val_recall: 0.0032 - val_auc: 0.5485
# Epoch 88/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 30878.8379 - fp: 253197.8750 - tn: 100123408.0000 - fn: 9727600.0000 - accuracy: 0.9094 - precision: 0.1087 - recall: 0.0032 - auc: 0.5487 - val_loss: 0.5042 - val_tp: 30907.0000 - val_fp: 253240.5625 - val_tn: 100685816.0000 - val_fn: 9781029.0000 - val_accuracy: 0.9094 - val_precision: 0.1088 - val_recall: 0.0031 - val_auc: 0.5487
# Epoch 89/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2481 - tp: 30934.7617 - fp: 253291.8906 - tn: 101245832.0000 - fn: 9836931.0000 - accuracy: 0.9094 - precision: 0.1088 - recall: 0.0031 - auc: 0.5488 - val_loss: 0.5044 - val_tp: 30970.0000 - val_fp: 253338.0000 - val_tn: 101808336.0000 - val_fn: 9890226.0000 - val_accuracy: 0.9094 - val_precision: 0.1089 - val_recall: 0.0031 - val_auc: 0.5488
# Epoch 90/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2483 - tp: 30986.3906 - fp: 253373.9844 - tn: 102368368.0000 - fn: 9946134.0000 - accuracy: 0.9094 - precision: 0.1090 - recall: 0.0031 - auc: 0.5489 - val_loss: 0.5064 - val_tp: 31005.0000 - val_fp: 253419.4375 - val_tn: 102930752.0000 - val_fn: 9999468.0000 - val_accuracy: 0.9094 - val_precision: 0.1090 - val_recall: 0.0031 - val_auc: 0.5489
# Epoch 91/100
#  - ETA: 2s - loss: 0.2490 - tp: 31019.6738 - fp: 253439.9844 - tn: 103229640.0000 - fn: 10036072.0000 - accuracy: 0.9094 - precision: 0.1090 - recall: 0.0031 - auc: 0.5490
# Epoch 92/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 31097.0332 - fp: 253549.3281 - tn: 104613352.0000 - fn: 10164579.0000 - accuracy: 0.9094 - precision: 0.1092 - recall: 0.0031 - auc: 0.5491 - val_loss: 0.5072 - val_tp: 31127.0000 - val_fp: 253595.4375 - val_tn: 105175792.0000 - val_fn: 10217871.0000 - val_accuracy: 0.9095 - val_precision: 0.1093 - val_recall: 0.0030 - val_auc: 0.5490
# Epoch 93/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 31155.5684 - fp: 253641.2500 - tn: 105735960.0000 - fn: 10273700.0000 - accuracy: 0.9095 - precision: 0.1094 - recall: 0.0030 - auc: 0.5490 - val_loss: 0.5045 - val_tp: 31181.0000 - val_fp: 253690.0000 - val_tn: 106298472.0000 - val_fn: 10327082.0000 - val_accuracy: 0.9095 - val_precision: 0.1095 - val_recall: 0.0030 - val_auc: 0.5490
# Epoch 94/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 31216.0645 - fp: 253732.3438 - tn: 106858496.0000 - fn: 10382907.0000 - accuracy: 0.9095 - precision: 0.1095 - recall: 0.0030 - auc: 0.5491 - val_loss: 0.5061 - val_tp: 31253.0000 - val_fp: 253787.4375 - val_tn: 107420920.0000 - val_fn: 10436271.0000 - val_accuracy: 0.9095 - val_precision: 0.1096 - val_recall: 0.0030 - val_auc: 0.5491
# Epoch 95/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 31281.7227 - fp: 253831.2344 - tn: 107980768.0000 - fn: 10492354.0000 - accuracy: 0.9095 - precision: 0.1097 - recall: 0.0030 - auc: 0.5491 - val_loss: 0.5057 - val_tp: 31311.0000 - val_fp: 253875.4375 - val_tn: 108543400.0000 - val_fn: 10545494.0000 - val_accuracy: 0.9095 - val_precision: 0.1098 - val_recall: 0.0030 - val_auc: 0.5492
# Epoch 96/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 31342.7031 - fp: 253912.1250 - tn: 109103464.0000 - fn: 10601391.0000 - accuracy: 0.9095 - precision: 0.1099 - recall: 0.0029 - auc: 0.5493 - val_loss: 0.5056 - val_tp: 31375.0000 - val_fp: 253958.0000 - val_tn: 109665904.0000 - val_fn: 10654700.0000 - val_accuracy: 0.9095 - val_precision: 0.1100 - val_recall: 0.0029 - val_auc: 0.5493
# Epoch 97/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 31398.6699 - fp: 254001.0938 - tn: 110225936.0000 - fn: 10710610.0000 - accuracy: 0.9095 - precision: 0.1100 - recall: 0.0029 - auc: 0.5493 - val_loss: 0.5041 - val_tp: 31426.0000 - val_fp: 254046.0000 - val_tn: 110788336.0000 - val_fn: 10763905.0000 - val_accuracy: 0.9096 - val_precision: 0.1101 - val_recall: 0.0029 - val_auc: 0.5494
# Epoch 98/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.2482 - tp: 31454.0977 - fp: 254086.5781 - tn: 111348624.0000 - fn: 10819728.0000 - accuracy: 0.9096 - precision: 0.1102 - recall: 0.0029 - auc: 0.5495 - val_loss: 0.5051 - val_tp: 31483.0000 - val_fp: 254132.0000 - val_tn: 111911040.0000 - val_fn: 10873108.0000 - val_accuracy: 0.9096 - val_precision: 0.1102 - val_recall: 0.0029 - val_auc: 0.5495
# Epoch 99/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.2482 - tp: 31510.2344 - fp: 254175.6406 - tn: 112470936.0000 - fn: 10929160.0000 - accuracy: 0.9096 - precision: 0.1103 - recall: 0.0029 - auc: 0.5495 - val_loss: 0.5056 - val_tp: 31538.0000 - val_fp: 254215.4375 - val_tn: 113033544.0000 - val_fn: 10982316.0000 - val_accuracy: 0.9096 - val_precision: 0.1104 - val_recall: 0.0029 - val_auc: 0.5496
# Epoch 100/100
#  - ETA: 1s - loss: 0.2486 - tp: 31558.6953 - fp: 254244.5156 - tn: 113453352.0000 - fn: 11027969.0000 - accuracy: 0.9096 - precision: 0.1104 - recall: 0.0029 - auc: 0.5496

# %%
train_predictions_baseline = model_baseline.predict(X_train, batch_size=BATCH_SIZE)
test_predictions_baseline = model_baseline.predict(X_test, batch_size=BATCH_SIZE)

# %%
print('Weight for class 0: {:.2f}'.format(weight_for_0))
print('Weight for class 1: {:.2f}'.format(weight_for_1))
model_weighted = keras.Sequential()
model_weighted.add(keras.layers.Dense(16,activation='relu',input_shape=(n_features,)))
model_weighted.add(keras.layers.Dropout(0.5))
model_weighted.add(keras.layers.Dense(1,activation='sigmoid'))
print('Built NN...')
model_weighted.compile(optimizer=keras.optimizers.Adam(lr=1e-3),loss=keras.losses.BinaryCrossentropy(),metrics=METRICS)
model_weighted.summary()
print('Compiled NN...')

model_weighted.load_weights(initial_weights)
weighted_history = model_weighted.fit(X_train,
                             y_train,
                             batch_size=BATCH_SIZE,
                             epochs=EPOCHS,
                             callbacks = [early_stopping],
                             validation_split=0.2, # The class weights go here
                             class_weight=class_weight)
# Out:
# Weight for class 0: 0.54
# Weight for class 1: 6.81
# Built NN...
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 16)                208
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 16)                0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 225
# Trainable params: 225
# Non-trainable params: 0
# _________________________________________________________________
# Compiled NN...
# Train on 985539 samples, validate on 246385 samples
# Epoch 1/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.8888 - tp: 34846.7852 - fp: 296910.5938 - tn: 114673600.0000 - fn: 11144254.0000 - accuracy: 0.9093 - precision: 0.1058 - recall: 0.0031 - auc: 0.5490 - val_loss: 1.3017 - val_tp: 42883.2305 - val_fp: 400366.6875 - val_tn: 115132752.0000 - val_fn: 11189506.0000 - val_accuracy: 0.9086 - val_precision: 0.0967 - val_recall: 0.0038 - val_auc: 0.5485
# Epoch 2/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.7432 - tp: 53386.4609 - fp: 535683.9375 - tn: 115557496.0000 - fn: 11234976.0000 - accuracy: 0.9076 - precision: 0.0910 - recall: 0.0047 - auc: 0.5481 - val_loss: 1.1976 - val_tp: 65426.2305 - val_fp: 679028.8125 - val_tn: 115976696.0000 - val_fn: 11276230.0000 - val_accuracy: 0.9066 - val_precision: 0.0879 - val_recall: 0.0058 - val_auc: 0.5476
# Epoch 3/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.7174 - tp: 78712.3672 - fp: 827473.3125 - tn: 116388496.0000 - fn: 11318865.0000 - accuracy: 0.9056 - precision: 0.0870 - recall: 0.0069 - auc: 0.5473 - val_loss: 1.1944 - val_tp: 91626.2266 - val_fp: 978546.6250 - val_tn: 116800008.0000 - val_fn: 11359308.0000 - val_accuracy: 0.9045 - val_precision: 0.0856 - val_recall: 0.0080 - val_auc: 0.5468
# Epoch 4/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.7053 - tp: 105561.5781 - fp: 1136567.0000 - tn: 117202088.0000 - fn: 11401271.0000 - accuracy: 0.9034 - precision: 0.0851 - recall: 0.0092 - auc: 0.5464 - val_loss: 1.1805 - val_tp: 118599.9922 - val_fp: 1292783.0000 - val_tn: 117608408.0000 - val_fn: 11441586.0000 - val_accuracy: 0.9024 - val_precision: 0.0840 - val_recall: 0.0103 - val_auc: 0.5459
# Epoch 5/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.6947 - tp: 132777.8125 - fp: 1449841.1250 - tn: 118011344.0000 - fn: 11483390.0000 - accuracy: 0.9013 - precision: 0.0839 - recall: 0.0114 - auc: 0.5455 - val_loss: 1.1883 - val_tp: 145961.9531 - val_fp: 1604015.3750 - val_tn: 118419808.0000 - val_fn: 11523492.0000 - val_accuracy: 0.9003 - val_precision: 0.0834 - val_recall: 0.0125 - val_auc: 0.5451
# Epoch 6/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.6882 - tp: 159387.5469 - fp: 1752440.3750 - tn: 118831392.0000 - fn: 11566052.0000 - accuracy: 0.8993 - precision: 0.0834 - recall: 0.0136 - auc: 0.5447 - val_loss: 1.1554 - val_tp: 173524.2500 - val_fp: 1902434.3750 - val_tn: 119243936.0000 - val_fn: 11605198.0000 - val_accuracy: 0.8984 - val_precision: 0.0836 - val_recall: 0.0147 - val_auc: 0.5443
# Epoch 7/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.6807 - tp: 189083.0781 - fp: 2048186.2500 - tn: 119658312.0000 - fn: 11645622.0000 - accuracy: 0.8974 - precision: 0.0845 - recall: 0.0160 - auc: 0.5439 - val_loss: 1.1485 - val_tp: 202389.6250 - val_fp: 2183576.0000 - val_tn: 120085560.0000 - val_fn: 11685599.0000 - val_accuracy: 0.8966 - val_precision: 0.0848 - val_recall: 0.0170 - val_auc: 0.5435
# Epoch 8/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6754 - tp: 217097.0312 - fp: 2315276.2500 - tn: 120514040.0000 - fn: 11726787.0000 - accuracy: 0.8958 - precision: 0.0857 - recall: 0.0182 - auc: 0.5432 - val_loss: 1.1490 - val_tp: 229817.3281 - val_fp: 2441571.5000 - val_tn: 120950288.0000 - val_fn: 11767444.0000 - val_accuracy: 0.8950 - val_precision: 0.0860 - val_recall: 0.0192 - val_auc: 0.5427
# Epoch 9/100
# 985539/985539 [==============================] - 6s 6us/step - loss: 0.6718 - tp: 243572.0625 - fp: 2558629.0000 - tn: 121393328.0000 - fn: 11809607.0000 - accuracy: 0.8943 - precision: 0.0869 - recall: 0.0202 - auc: 0.5424 - val_loss: 1.1353 - val_tp: 255666.0469 - val_fp: 2671666.7500 - val_tn: 121842800.0000 - val_fn: 11850861.0000 - val_accuracy: 0.8937 - val_precision: 0.0873 - val_recall: 0.0211 - val_auc: 0.5420
# Epoch 10/100
# 985539/985539 [==============================] - 5s 5us/step - loss: 0.6695 - tp: 269060.9375 - fp: 2780494.5000 - tn: 122294088.0000 - fn: 11893419.0000 - accuracy: 0.8931 - precision: 0.0882 - recall: 0.0221 - auc: 0.5417 - val_loss: 1.1392 - val_tp: 280404.3438 - val_fp: 2883083.0000 - val_tn: 122754072.0000 - val_fn: 11935379.0000 - val_accuracy: 0.8925 - val_precision: 0.0886 - val_recall: 0.0230 - val_auc: 0.5413
# Epoch 11/100
# 985539/985539 [==============================] - 5s 6us/step - loss: 0.6681 - tp: 292378.3750 - fp: 2971085.7500 - tn: 123226368.0000 - fn: 11979226.0000 - accuracy: 0.8920 - precision: 0.0896 - recall: 0.0238 - auc: 0.5410 - val_loss: 1.1166 - val_tp: 302833.3125 - val_fp: 3058238.5000 - val_tn: 123701624.0000 - val_fn: 12022224.0000 - val_accuracy: 0.8916 - val_precision: 0.0901 - val_recall: 0.0246 - val_auc: 0.5406
# Restoring model weights from the end of the best epoch.
# Epoch 00011: early stopping

# %%
plot_metrics(weighted_history)
plt.show()

# %%
train_predictions_weighted = model_weighted.predict(X_train, batch_size=BATCH_SIZE)
test_predictions_weighted = model_weighted.predict(X_test, batch_size=BATCH_SIZE)

# %%
weighted_results = model_weighted.evaluate(X_test, y_test,
                                           batch_size=BATCH_SIZE, verbose=0)
for name, value in zip(model_weighted.metrics_names, weighted_results):
  print(name, ': ', value)
print()

plot_cm(y_test, test_predictions_weighted)
# Out:
# loss :  0.5054300428520718
# tp :  307812.3125
# fp :  3070600.25
# tn :  123941816.0
# fn :  12041971.0
# accuracy :  0.8915504217147827
# precision :  0.0911116823554039
# recall :  0.024924524128437042
# auc :  0.54053795337677
#
# Legitimate Transactions Detected (True Negatives):  303746
# Legitimate Transactions Incorrectly Detected (False Positives):  443
# Fraudulent Transactions Missed (False Negatives):  3762
# Fraudulent Transactions Detected (True Positives):  1
# Total Fraudulent Transactions:  3763

# %%
plot_roc("Train Baseline", y_train, train_predictions_baseline, color=colors[0])
plot_roc("Test Baseline", y_test, test_predictions_baseline, color=colors[0], linestyle='--')

plot_roc("Train Weighted", y_train, train_predictions_weighted, color=colors[1])
plot_roc("Test Weighted", y_test, test_predictions_weighted, color=colors[1], linestyle='--')


plt.legend(loc='lower right')
plt.show()
